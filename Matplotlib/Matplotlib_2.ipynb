# %% [markdown]
# # 📊 Basic Charts in Data Visualization
#
# ## Chart Types Overview
#
# ### 🔹 Bar Chart
# **Purpose:** Compare values across different categories
#
# **When to use:**
# - Comparing quantities between distinct groups
# - Showing rankings or differences
# - When category names are long
#
# **Example:**
# ```
# Sales by Product
# Laptops:    ████████████ (120 units)
# Phones:     ████████ (80 units)
# Tablets:    █████ (50 units)
# ```
#
# ---
#
# ### 🔹 Pie Chart
# **Purpose:** Show parts of a whole (proportions)
#
# **When to use:**
# - Displaying percentage distribution
# - When you have 3-6 categories max
# - Total adds up to 100%
#
# **Example:**
# ```
# Budget Allocation
# 🟦 Marketing: 40%
# 🟨 Development: 35%
# 🟥 Operations: 25%
# ```
#
# ⚠️ **Avoid when:** You have many categories or need precise comparisons
#
# ---
#
# ### 🔹 Histogram
# **Purpose:** Show distribution of continuous numerical data
#
# **When to use:**
# - Understanding data frequency
# - Identifying patterns in measurements
# - Finding the most common value ranges
#
# **Example:**
# ```
# Student Test Scores
# 0-20:   ▂ (5 students)
# 20-40:  ▄ (15 students)
# 40-60:  ████ (45 students)  ← Most common
# 60-80:  ▆ (25 students)
# 80-100: ▃ (10 students)
# ```
#
# **Before:** Individual scores → `45, 67, 89, 52, 78, 55, 61...`
# **After:** Grouped into ranges showing the pattern
#
# ---
#
# ## 📐 What is Data Spread?
#
# **Data spread** measures how scattered or concentrated your values are.
#
# ### Key Concepts:
#
# **Range:** Distance between smallest and largest value
# - Example: Test scores from 35 to 95 → Range = 60
#
# **Variance:** How far each value is from the average
# - Low spread: Values clustered together (65, 67, 68, 70)
# - High spread: Values scattered widely (20, 45, 70, 95)
#
# **Why it matters:**
# - Helps identify outliers (unusual values)
# - Shows consistency in your data
# - Reveals patterns and trends
#
# ---
#
# ## 🎯 Quick Decision Guide
#
# | Your Data | Best Chart |
# |-----------|------------|
# | Categories with quantities | **Bar Chart** |
# | Percentages of a whole | **Pie Chart** |
# | Continuous number ranges | **Histogram** |
#
# **Pro Tip:** Histograms show "how many" in each range, Bar charts show "how much" for each category

# %% [markdown]
# # 📊 Bar Chart - Complete Guide
#
# ## What is a Bar Chart?
#
# A **bar chart** is used for quick comparison between categories. Each bar's length is directly proportional to its value.
#
# **Simple Rule:** Big bar = Big value 📏
#
# ---
#
# ## 📦 Sample Dataset
#
# **Products vs Sales**
#
# | Product | Sales (₹) |
# |---------|-----------|
# | A | 1000 |
# | B | 1500 |
# | C | 800 |
# | D | 1200 |
#
# ---
#
# ## 🔧 Syntax Breakdown
#
# ```python
# plt.bar(x, height, width, label)
# ```
#
# ### Parameters Explained
#
# | Parameter | Type | Required | Description | Example |
# |-----------|------|----------|-------------|---------|
# | `x` | array/list | ✅ **Yes** | Position of bars on x-axis (categories) | `['A', 'B', 'C', 'D']` |
# | `height` | array/list | ✅ **Yes** | Height of each bar (values/sales) | `[1000, 1500, 800, 1200]` |
# | `width` | float | ❌ No | Thickness of bars (default: 0.8) | `0.5` (thinner), `1.0` (wider) |
# | `label` | string | ❌ No | Name for legend | `'Sales Data'` |
#
# ---
#
# ## 💻 Professional Implementation
#
# ```python
# import matplotlib.pyplot as plt
#
# # Data
# products = ['Product A', 'Product B', 'Product C', 'Product D']
# sales = [1000, 1500, 800, 1200]
#
# # Create bar chart
# plt.bar(products, sales, width=0.6, label='Q1 Sales')
#
# # Styling
# plt.xlabel('Products')
# plt.ylabel('Sales (₹)')
# plt.title('Product Sales Comparison')
# plt.legend()
# plt.grid(axis='y', alpha=0.3)
#
# # Display
# plt.show()
# ```
# ---
#
# ## 🎨 Grid Styling
#
# ```python
# plt.grid(axis='y', alpha=0.3)
# ```
#
# ### Parameters Explained
#
# | Parameter | Type | Required | Description | Example |
# |-----------|------|----------|-------------|---------|
# | `axis` | string | ❌ No | Which axis to show gridlines | `'x'`, `'y'`, `'both'` (default) |
# | `alpha` | float | ❌ No | Transparency level (0=invisible, 1=solid) | `0.3` (light), `0.7` (visible) |
#
# **Why use grid?**
# - Makes it easier to read exact values
# - Helps compare bar heights quickly
# - `alpha=0.3` keeps grid subtle and non-distracting
#
# **Without Grid:**
# ```
# Bars only - harder to estimate exact values
# ```
#
# **With Grid (alpha=0.3):**
# ```
# Bars with light horizontal lines - easy to read values at 1000, 1200, 1500
# ```
#
# ---
#
# ## 🎯 Key Takeaways
#
# ✅ Bar length is **directly proportional** to value
# ✅ Perfect for **comparing categories**
# ✅ Only `x` and `height` are mandatory
# ✅ Use `width` to adjust bar thickness (0.1 to 1.0)
# ✅ Use `label` when showing multiple datasets
# ✅ Add `grid` with low `alpha` for better readability

# %%
import matplotlib.pyplot as plt

# %%
# Data
products = ['Product A', 'Product B', 'Product C', 'Product D']
sales = [1000, 1500, 800, 1200]

# Create bar chart
plt.bar(products, sales, width=0.4, label='Q1 Sales', color = 'orange')

# Styling
plt.xlabel('Products')
plt.ylabel('Sales (₹)')
plt.title('Product Sales Comparison')
plt.legend()
plt.grid(alpha = 0.3, axis='y')

# Display
plt.show()

# %%
# Data
products = ['Product A', 'Product B', 'Product C', 'Product D']
sales = [1000, 1500, 800, 1200]

# Create horizontal bar chart
plt.barh(products, sales, color='orange', label='Q1 Sales')   # for horizontal bar graph

# Styling
plt.ylabel('Products')
plt.xlabel('Sales (₹)')
plt.title('Product Sales Comparison')
plt.legend()
plt.grid(alpha=0.3, axis='x')

# Display
plt.show()

# %% [markdown]
# # 🥧 Pie Chart - Complete Guide
#
# ## What is a Pie Chart?
#
# A **pie chart** shows how different parts make up a whole. Each slice represents a proportion (percentage) of the total.
#
# **Simple Rule:** Bigger slice = Bigger share 🍰
#
# ---
#
# ## 📦 Sample Dataset
#
# **Company Profit by Region**
#
# | Region | Profit (₹) |
# |--------|------------|
# | North | 3000 |
# | South | 2000 |
# | East | 18000 |
# | West | 1000 |
#
# **Total Profit:** ₹24,000
#
# ---
#
# ## 🔧 Syntax Breakdown
#
# ```python
# plt.pie(values, labels, colors, autopct, startangle, explode, shadow)
# ```
#
# ### Parameters Explained
#
# | Parameter | Type | Required | Description | Example |
# |-----------|------|----------|-------------|---------|
# | `values` | array/list | ✅ **Yes** | Data values (profit amounts) | `[3000, 2000, 18000, 1000]` |
# | `labels` | array/list | ❌ No | Name for each slice | `['North', 'South', 'East', 'West']` |
# | `colors` | array/list | ❌ No | Custom colors for slices | `['#FF6B6B', '#4ECDC4', '#45B7D1', '#FFA07A']` |
# | `autopct` | string/function | ❌ No | Display percentages on slices | `'%1.1f%%'` (shows: 12.5%) |
# | `startangle` | int | ❌ No | Rotation angle (default: 0) | `90` (starts from top) |
# | `explode` | array/tuple | ❌ No | Separate slice from center | `(0, 0, 0.1, 0)` (pulls 3rd slice) |
# | `shadow` | bool | ❌ No | Add shadow effect | `True` or `False` |
#
# ---
#
# ## 🔢 Understanding `autopct`
#
# **autopct** automatically displays percentages on pie slices.
#
# ### Format String Breakdown
#
# | Format | Meaning | Output Example |
# |--------|---------|-----------------|
# | `'%1.1f%%'` | 1 decimal place | `12.5%` |
# | `'%1.2f%%'` | 2 decimal places | `12.50%` |
# | `'%.0f%%'` | No decimals (whole number) | `13%` |
# | `'%d%%'` | Integer only | `12%` |
#
# **Explanation:**
# - `%1.1f` = Show 1 digit before decimal, 1 digit after
# - `%%` = Display the % symbol (first % escapes the second)
#
# ---
#
# ## 💻 Professional Implementation
#
# ```python
# import matplotlib.pyplot as plt
#
# # Data
# regions = ['North', 'South', 'East', 'West']
# profits = [3000, 2000, 18000, 1000]
# colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#FFA07A']
#
# # Highlight the largest slice (East)
# explode = (0, 0, 0.1, 0)
#
# # Create pie chart
# plt.pie(profits,
#         labels=regions,
#         colors=colors,
#         autopct='%1.1f%%',
#         startangle=90,
#         explode=explode,
#         shadow=True)
#
# # Styling
# plt.title('Regional Profit Distribution')
# plt.axis('equal')  # Makes pie circular
#
# # Display
# plt.show()
# ```
# ---
#
# ## 🎯 Common Use Cases
#
# | autopct Format | Best For | Example Output |
# |----------------|----------|----------------|
# | `'%1.1f%%'` | **General use** (standard) | `12.5%` |
# | `'%.0f%%'` | Simple/clean look | `13%` |
# | `'%1.2f%%'` | Precise analysis | `12.50%` |
#
# ---
#
# ## ⚠️ Best Practices
#
# ✅ Use for **3-6 categories** maximum
# ✅ All values must be **positive**
# ✅ Set `startangle=90` to start from top
# ✅ Use `explode` to highlight important slices
# ✅ Always use `autopct` to show percentages
# ❌ Avoid for too many categories (use bar chart instead)

# %%
# Data
regions = ['North', 'South', 'East', 'West']
profits = [3000, 2000, 18000, 1000]
colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#FFA07A']

# Highlight the largest slice (East)
explode = (0, 0, 0.1, 0)

# Create pie chart
plt.pie(profits,
        labels=regions,
        colors=colors,
        autopct='%1.1f%%',
        startangle=90,
        explode=explode,
        shadow=True)

# Styling
plt.title('Regional Profit Distribution')
plt.axis('equal')  # Makes pie circular

# Display
plt.show()

# %% [markdown]
# # 📊 Histogram - Complete Guide
#
# ## What is a Histogram?
#
# A **histogram** shows the distribution of continuous numerical data by grouping values into ranges (bins). It reveals patterns like which ranges are most common.
#
# **Simple Rule:** Taller bar = More values in that range 📈
#
# ---
#
# ## 📦 Sample Dataset
#
# **100 Students Exam Scores**
#
# | Score Range | Number of Students |
# |-------------|-------------------|
# | 0-20 | 5 |
# | 20-40 | 12 |
# | 40-60 | 28 |
# | 60-80 | 35 |
# | 80-100 | 20 |
#
# **Raw Data:** `[45, 67, 89, 52, 78, 55, 61, 73, 82, 91, ...]` (100 scores)
#
# ---
#
# ## 🔧 Syntax Breakdown
#
# ```python
# plt.hist(data, bins, color, edgecolor, alpha, range, density)
# ```
#
# ### Parameters Explained
#
# | Parameter | Type | Required | Description | Example |
# |-----------|------|----------|-------------|---------|
# | `data` | array/list | ✅ **Yes** | All individual values (student scores) | `[45, 67, 89, 52, 78, ...]` |
# | `bins` | int/array | ❌ No | Number of ranges (default: 10) | `5` (5 ranges) or `[0,20,40,60,80,100]` |
# | `color` | string | ❌ No | Bar fill color | `'skyblue'`, `'#45B7D1'` |
# | `edgecolor` | string | ❌ No | Bar border color | `'black'`, `'white'` |
# | `alpha` | float | ❌ No | Transparency (0=invisible, 1=solid) | `0.7` (semi-transparent) |
# | `range` | tuple | ❌ No | Min and max values to include | `(0, 100)` |
# | `density` | bool | ❌ No | Show as probability (default: False) | `True` (normalizes to 1.0) |
#
# ---
#
# ## 🔢 Understanding `bins`
#
# **bins** determines how data is grouped into ranges.
#
# ### Bin Options
#
# | Bins Value | Meaning | Result |
# |------------|---------|--------|
# | `5` | 5 equal ranges | `[0-20, 20-40, 40-60, 60-80, 80-100]` |
# | `10` | 10 equal ranges | `[0-10, 10-20, 20-30, ..., 90-100]` |
# | `[0,50,100]` | Custom ranges | `[0-50, 50-100]` (2 bins) |
# | `'auto'` | Automatic (recommended) | Python decides optimal bins |
#
# **Pro Tip:** More bins = More detail, but too many makes it messy. Start with 10-20 bins.
#
# ---
#
# ## 💻 Professional Implementation
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Sample data: 100 student exam scores
# scores = [45, 67, 89, 52, 78, 55, 61, 73, 82, 91, 48, 76,
#           88, 63, 70, 58, 85, 92, 44, 68, ...]  # 100 scores
#
# # Create histogram
# plt.hist(scores,
#          bins=5,
#          color='#45B7D1',
#          edgecolor='black',
#          alpha=0.7,
#          range=(0, 100))
#
# # Styling
# plt.xlabel('Score Range')
# plt.ylabel('Number of Students')
# plt.title('Exam Score Distribution')
# plt.xticks([0, 20, 40, 60, 80, 100])
# plt.grid(axis='y', alpha=0.3)
#
# # Display
# plt.show()
# ```
#
# ---
#
# ## 🎯 Histogram vs Bar Chart
#
# | Feature | Histogram | Bar Chart |
# |---------|-----------|-----------|
# | **Data Type** | Continuous numbers | Discrete categories |
# | **X-axis** | Number ranges (bins) | Category names |
# | **Purpose** | Show distribution pattern | Compare categories |
# | **Example** | Student ages, heights, scores | Products, cities, months |
# | **Gaps** | No gaps between bars | Gaps between bars |
#
# ---
#
# ## 📊 Common Bin Configurations
#
# | Use Case | Bins | Reason |
# |----------|------|--------|
# | **Quick overview** | `5-10` | Broad patterns |
# | **Detailed analysis** | `20-30` | Fine-grained view |
# | **Age groups** | `[0,18,35,50,65,100]` | Custom age ranges |
# | **Grades** | `[0,40,50,60,70,80,90,100]` | Grade boundaries |
#
# ---
#
# ## ⚠️ Best Practices
#
# ✅ Use for **continuous numerical data**
# ✅ Choose appropriate `bins` (not too few, not too many)
# ✅ Add `edgecolor='black'` for clarity
# ✅ Use `alpha=0.7` when overlapping histograms
# ✅ Always label axes clearly
# ❌ Don't use for categorical data (use bar chart)
# ❌ Avoid too many bins (makes it noisy)

# %%
# Sample data: 100 student exam scores
scores = [45, 67, 89, 52, 78, 55, 61, 73, 82, 91, 48, 76,
          88, 63, 70, 58, 85, 92, 44, 68]  # 100 scores

# Create histogram
plt.hist(scores,
         bins=5,
         color='#45B7D1',
         edgecolor='black',
         alpha=0.7,
         range=(0, 100))

# Styling
plt.xlabel('Score Range')
plt.ylabel('Number of Students')
plt.title('Exam Score Distribution')
plt.xticks([0, 20, 40, 60, 80, 100])
plt.grid(axis='y', alpha=0.3)

# Display
plt.show()

# %% [markdown]
# # 🔵 Scatter Plot - Complete Guide
#
# ## What is a Scatter Plot?
#
# A **scatter plot** shows the relationship between two numerical variables. Each point represents one observation with two values (x, y). It helps identify patterns, correlations, and clusters.
#
# **Simple Rule:** Points pattern reveals relationship 📍
#
# ---
#
# ## 🎯 Why Use Scatter Plots?
#
# **Problem:** Does studying more hours lead to better exam scores?
#
# **Solution:** Scatter plot shows if there's a relationship:
# - **Positive:** More hours → Higher scores (upward trend)
# - **Negative:** More hours → Lower scores (downward trend)
# - **No pattern:** Hours don't affect scores (random scatter)
#
# ---
#
# ## 📦 Sample Dataset
#
# **Student Study Hours vs Exam Scores**
#
# | Student | Study Hours (X) | Exam Score (Y) |
# |---------|-----------------|----------------|
# | 1 | 2 | 45 |
# | 2 | 4 | 62 |
# | 3 | 6 | 71 |
# | 4 | 3 | 55 |
# | 5 | 8 | 85 |
# | 6 | 5 | 68 |
# | 7 | 7 | 78 |
# | 8 | 1 | 38 |
#
# **Each point = One student with (hours, score)**
#
# ---
#
# ## 🔧 Syntax Breakdown
#
# ```python
# plt.scatter(x, y, s, c, marker, alpha, edgecolors, label)
# ```
#
# ### Parameters Explained
#
# | Parameter | Type | Required | Description | Example |
# |-----------|------|----------|-------------|---------|
# | `x` | array/list | ✅ **Yes** | X-axis values (study hours) | `[2, 4, 6, 3, 8, 5, 7, 1]` |
# | `y` | array/list | ✅ **Yes** | Y-axis values (exam scores) | `[45, 62, 71, 55, 85, 68, 78, 38]` |
# | `s` | int/array | ❌ No | Point size (default: 20) | `50` (medium), `100` (large) |
# | `c` | string/array | ❌ No | Point color(s) | `'blue'`, `'#FF6B6B'` |
# | `marker` | string | ❌ No | Point shape (default: 'o') | `'o'` (circle), `'^'` (triangle), `'s'` (square) |
# | `alpha` | float | ❌ No | Transparency (0=invisible, 1=solid) | `0.6` (semi-transparent) |
# | `edgecolors` | string | ❌ No | Point border color | `'black'`, `'white'` |
# | `label` | string | ❌ No | Legend label | `'Student Data'` |
#
# ---
#
# ## 🎨 Understanding `marker`
#
# **marker** determines the shape of each point.
#
# ### Common Marker Styles
#
# | Marker | Shape | Use Case |
# |--------|-------|----------|
# | `'o'` | ● Circle | Default, general use |
# | `'s'` | ■ Square | Categorical grouping |
# | `'^'` | ▲ Triangle | Pointing upward trends |
# | `'*'` | ★ Star | Highlighting outliers |
# | `'+'` | ✚ Plus | Intersection points |
# | `'x'` | ✕ Cross | Negative/errors |
# | `'D'` | ◆ Diamond | Special observations |
#
# ---
#
# ## 💻 Professional Implementation
#
# ```python
# import matplotlib.pyplot as plt
#
# # Data
# study_hours = [2, 4, 6, 3, 8, 5, 7, 1]
# exam_scores = [45, 62, 71, 55, 85, 68, 78, 38]
#
# # Create scatter plot
# plt.scatter(study_hours,
#             exam_scores,
#             s=100,
#             c='#45B7D1',
#             marker='o',
#             alpha=0.7,
#             edgecolors='black',
#             label='Students')
#
# # Styling
# plt.xlabel('Study Hours')
# plt.ylabel('Exam Score')
# plt.title('Study Hours vs Exam Performance')
# plt.grid(True, alpha=0.3)
# plt.legend()
#
# # Display
# plt.show()
# ```
#
# ---
#
# ## 🔍 Identifying Patterns
#
# ### Types of Relationships
#
# | Pattern | Visual | Interpretation |
# |---------|--------|----------------|
# | **Positive** | ↗️ Upward slope | Both variables increase together |
# | **Negative** | ↘️ Downward slope | One increases, other decreases |
# | **No correlation** | Random scatter | No relationship between variables |
# | **Clustering** | Groups of points | Distinct categories/groups exist |
#
# ---
#
# ## 🎯 Scatter vs Other Charts
#
# | Feature | Scatter Plot | Line Chart | Bar Chart |
# |---------|--------------|------------|-----------|
# | **Shows** | Relationship | Trend over time | Category comparison |
# | **Data Type** | Two numerical | Sequential | Categorical + numerical |
# | **Points** | Individual observations | Connected | No points |
# | **Best For** | Correlation analysis | Time series | Comparing groups |
#
# ---
#
# ## 📊 Advanced: Point Sizing
#
# You can vary point size based on a third variable:
#
# ```python
# # Point size represents number of students with same values
# sizes = [50, 100, 150, 75, 200, 125, 175, 50]
#
# plt.scatter(study_hours, exam_scores, s=sizes, alpha=0.6)
# ```
#
# **Result:** Bigger points = More students with those values
#
# ---
#
# ## ⚠️ Best Practices
#
# ✅ Use for **two continuous numerical variables**
# ✅ Check for **correlation patterns** (upward/downward trends)
# ✅ Identify **outliers** (points far from the pattern)
# ✅ Use `alpha=0.6` when points overlap
# ✅ Add `edgecolors` for better visibility
# ✅ Look for **clusters** (grouped points)
# ❌ Don't connect points with lines (unless time series)
# ❌ Avoid when one variable is categorical

# %%
# Data
study_hours = [2, 4, 6, 3, 8, 5, 7, 1]
exam_scores = [45, 62, 71, 55, 85, 68, 78, 38]

# Create scatter plot
plt.scatter(study_hours,
            exam_scores,
            s=100,
            c='#45B7D1',
            marker='^',
            alpha=0.7,
            edgecolors='black',
            label='Students')

# Styling
plt.xlabel('Study Hours')
plt.ylabel('Exam Score')
plt.title('Study Hours vs Exam Performance')
plt.grid(True, alpha=0.3)
plt.legend()

# Display
plt.show()

# %% [markdown]
# ## 📊 Comparing Multiple Datasets
#
# You can plot multiple scatter plots on the same chart to compare different groups.
#
# ### Example: Class A vs Class B Performance
#
# ```python
# import matplotlib.pyplot as plt
#
# # Dataset 1: Class A
# plt.scatter([1, 2, 3], [50, 60, 70],
#             c='blue',
#             label='Class A',
#             s=100,
#             alpha=0.7)
#
# # Dataset 2: Class B
# plt.scatter([1, 2, 3, 5], [5, 45, 70, 50],
#             c='green',
#             label='Class B',
#             s=100,
#             alpha=0.7)
#
# # Styling
# plt.xlabel('Study Hours')
# plt.ylabel('Exam Score')
# plt.title('Study Hours vs Exam Performance')
# plt.grid(True, alpha=0.3)
# plt.legend()
#
# plt.show()
# ```
# ---
# **Key Points:**
# - Use different `c` (color) for each dataset
# - Always add `label` parameter for each dataset
# - Call `plt.legend()` to show which color represents which group
# - Both datasets appear on the same chart for easy comparison
#
# ---
#
# ## ⚠️ Best Practices
#
# ✅ Use for **two continuous numerical variables**
# ✅ Check for **correlation patterns** (upward/downward trends)
# ✅ Identify **outliers** (points far from the pattern)
# ✅ Use `alpha=0.6` when points overlap
# ✅ Add `edgecolors` for better visibility
# ✅ Look for **clusters** (grouped points)
# ❌ Don't connect points with lines (unless time series)
# ❌ Avoid when one variable is categorical

# %%
# Dataset 1: Class A
plt.scatter([1, 2, 3], [50, 60, 70],
            c='blue',
            label='Class A',
            s=100,
            alpha=0.7)

# Dataset 2: Class B
plt.scatter([1, 2, 3, 5], [5, 45, 70, 50],
            c='green',
            label='Class B',
            s=100,
            alpha=0.7)

# Styling
plt.xlabel('Study Hours')
plt.ylabel('Exam Score')
plt.title('Study Hours vs Exam Performance')
plt.grid(True, alpha=0.3)
plt.legend()

plt.show()

# %% [markdown]
# # 🎨 Subplots - Complete Guide
#
# ## What are Subplots?
#
# **Subplots** allow you to display multiple charts on the same page/canvas. Instead of creating separate figures, you divide one canvas into sections (grid layout).
#
# **Simple Rule:** Multiple charts, one canvas 📊➕📈
#
# ---
#
# ## 🎯 Why Use Subplots?
#
# ### Problem
# You have:
# - Line chart for **Sales** over time
# - Bar chart for **Expenses** by category
#
# **Challenge:** Need to compare both, but they're on separate pages!
#
# ### Solution: Subplots
#
# **Benefits:**
# - ✅ **Compare side-by-side** - Easy visual comparison
# - ✅ **Quick analysis** - View related datasets together
# - ✅ **Save space** - One canvas instead of multiple
# - ✅ **Professional reports** - Clean, organized layout
#
# **Example Grid:**
# ```
# ┌─────────────┬─────────────┐
# │   Chart 1   │   Chart 2   │
# │   (Sales)   │ (Expenses)  │
# └─────────────┴─────────────┘
#     1 Canvas, 2 Sections
# ```
#
# ---
#
# ## 🔧 Method 1: Quick Subplot Creation
#
# ### Syntax
#
# ```python
# plt.subplot(nrows, ncols, index)
# ```
#
# ### Parameters Explained
#
# | Parameter | Type | Required | Description | Example |
# |-----------|------|----------|-------------|---------|
# | `nrows` | int | ✅ **Yes** | Number of rows in grid | `2` (2 rows) |
# | `ncols` | int | ✅ **Yes** | Number of columns in grid | `3` (3 columns) |
# | `index` | int | ✅ **Yes** | Position (1-based, left to right, top to bottom) | `1` (first position) |
#
# ### Index Numbering (1-based)
#
# For a 2×2 grid:
# ```
# ┌───────┬───────┐
# │   1   │   2   │  ← Row 1
# ├───────┼───────┤
# │   3   │   4   │  ← Row 2
# └───────┴───────┘
# ```
#
# ### Professional Example
#
# ```python
# import matplotlib.pyplot as plt
#
# # Sample data
# months = ['Jan', 'Feb', 'Mar', 'Apr']
# sales = [100, 150, 130, 170]
# expenses = [80, 90, 85, 95]
#
# # Create subplot 1: Line chart (Sales)
# plt.subplot(1, 2, 1)  # 1 row, 2 columns, position 1
# plt.plot(months, sales, marker='o', color='#45B7D1')
# plt.title('Monthly Sales')
# plt.xlabel('Month')
# plt.ylabel('Sales (₹1000s)')
# plt.grid(True, alpha=0.3)
#
# # Create subplot 2: Bar chart (Expenses)
# plt.subplot(1, 2, 2)  # 1 row, 2 columns, position 2
# plt.bar(months, expenses, color='#FF6B6B', alpha=0.7)
# plt.title('Monthly Expenses')
# plt.xlabel('Month')
# plt.ylabel('Expenses (₹1000s)')
# plt.grid(axis='y', alpha=0.3)
#
# plt.tight_layout()
# plt.show()
# ```
#
# **Layout:** `(1, 2, 1)` and `(1, 2, 2)` = 1 row, 2 columns side-by-side
#
# ---
#
# ## 🔧 Method 2: Advanced Subplot (Recommended)
#
# ### Syntax
#
# ```python
# fig, ax = plt.subplots(nrows, ncols, figsize=(width, height))
# ```
#
# ### Parameters Explained
#
# | Parameter | Type | Required | Description | Example |
# |-----------|------|----------|-------------|---------|
# | `nrows` | int | ❌ No | Number of rows (default: 1) | `2` |
# | `ncols` | int | ❌ No | Number of columns (default: 1) | `2` |
# | `figsize` | tuple | ❌ No | Canvas size in inches (width, height) | `(12, 5)` |
#
# **Returns:**
# - `fig` = Figure object (entire canvas)
# - `ax` = Array of axes (individual subplots)
#
# ### Professional Example
#
# ```python
# import matplotlib.pyplot as plt
#
# # Sample data
# months = ['Jan', 'Feb', 'Mar', 'Apr']
# sales = [100, 150, 130, 170]
# expenses = [80, 90, 85, 95]
#
# # Create 1 row, 2 columns of subplots
# fig, ax = plt.subplots(1, 2, figsize=(12, 5))
#
# # Subplot 1: Line chart (Sales)
# ax[0].plot(months, sales, marker='o', color='#45B7D1', linewidth=2)
# ax[0].set_title('Monthly Sales', fontsize=14, fontweight='bold')
# ax[0].set_xlabel('Month')
# ax[0].set_ylabel('Sales (₹1000s)')
# ax[0].grid(True, alpha=0.3)
#
# # Subplot 2: Bar chart (Expenses)
# ax[1].bar(months, expenses, color='#FF6B6B', alpha=0.7)
# ax[1].set_title('Monthly Expenses', fontsize=14, fontweight='bold')
# ax[1].set_xlabel('Month')
# ax[1].set_ylabel('Expenses (₹1000s)')
# ax[1].grid(axis='y', alpha=0.3)
#
# plt.tight_layout()
# plt.show()
# ```
#
# ### Accessing Subplots
#
# | Grid Size | Access Method | Example |
# |-----------|---------------|---------|
# | 1 row, 2 cols | `ax[0]`, `ax[1]` | `ax[0].plot(...)` |
# | 2 rows, 2 cols | `ax[0,0]`, `ax[0,1]`, `ax[1,0]`, `ax[1,1]` | `ax[0,1].bar(...)` |
# | 3 rows, 1 col | `ax[0]`, `ax[1]`, `ax[2]` | `ax[2].scatter(...)` |
#
# ---
#
# ## 🎨 What is `tight_layout()`?
#
# ### Problem: Overlapping Elements
#
# Without `tight_layout()`:
# ```
# ┌─────────────┬─────────────┐
# │   Chart 1   │   Chart 2   │
# │   Title─────┼→overlaps    │
# │   Label──overlaps         │
# └─────────────┴─────────────┘
#       ❌ Messy layout
# ```
#
# ### Solution: `tight_layout()`
#
# ```python
# plt.tight_layout()
# ```
#
# **What it does:**
# - Automatically adjusts spacing between subplots
# - Prevents titles, labels, and axes from overlapping
# - Creates clean, professional-looking layouts
#
# With `tight_layout()`:
# ```
# ┌──────────┬──────────┐
# │ Chart 1  │ Chart 2  │
# │          │          │
# │          │          │
# └──────────┴──────────┘
#       ✅ Clean layout
# ```
#
# ### When to Use
#
# ✅ **ALWAYS use** when creating subplots
# ✅ Must be called **BEFORE** `plt.show()`
# ✅ Prevents overlapping titles and labels
# ✅ Essential for multi-subplot layouts
#
# ```python
# # Correct order
# plt.subplot(1, 2, 1)
# plt.plot(x, y)
#
# plt.subplot(1, 2, 2)
# plt.bar(x, y)
#
# plt.tight_layout()  # ← Before show()
# plt.show()
# ```
#
# ---
#
# ## 📐 Common Subplot Layouts
#
# | Layout | Code | Use Case |
# |--------|------|----------|
# | **Side-by-side** | `plt.subplots(1, 2)` | Compare 2 charts horizontally |
# | **Stacked** | `plt.subplots(2, 1)` | Compare 2 charts vertically |
# | **2×2 Grid** | `plt.subplots(2, 2)` | Show 4 related charts |
# | **3×1 Column** | `plt.subplots(3, 1)` | Time series progression |
# | **1×3 Row** | `plt.subplots(1, 3)` | Before-During-After comparison |
#
# ---
#
# ## 🎯 Method Comparison
#
# | Feature | `plt.subplot()` | `plt.subplots()` |
# |---------|-----------------|------------------|
# | **Syntax** | Simple, quick | More flexible |
# | **Access** | Current subplot only | All subplots via array |
# | **Control** | Basic | Advanced (figure size, etc.) |
# | **Recommended** | Small projects | Professional work |
# | **Code length** | Shorter | Slightly longer |
#
# ---
#
# ## ⚠️ Best Practices
#
# ✅ Use `plt.subplots()` for better control and readability
# ✅ Set appropriate `figsize` - default is often too small
# ✅ **ALWAYS** use `plt.tight_layout()` to avoid overlaps
# ✅ Use descriptive titles for each subplot
# ✅ Keep consistent styling across subplots (colors, fonts)
# ✅ Limit to 6-9 subplots max (too many = confusing)
# ❌ Don't forget `plt.tight_layout()` - causes messy layouts
# ❌ Don't make subplots too small (use appropriate figsize)

# %%
# Sample data
months = ['Jan', 'Feb', 'Mar', 'Apr']
sales = [100, 150, 130, 170]
expenses = [80, 90, 85, 95]

# Create subplot 1: Line chart (Sales)
plt.subplot(1, 2, 1)  # 1 row, 2 columns, position 1
plt.plot(months, sales, marker='o', color='#45B7D1')
plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Sales (₹1000s)')
plt.grid(True, alpha=0.3)

# Create subplot 2: Bar chart (Expenses)
plt.subplot(1, 2, 2)  # 1 row, 2 columns, position 2
plt.bar(months, expenses, color='#FF6B6B', alpha=0.7)
plt.title('Monthly Expenses')
plt.xlabel('Month')
plt.ylabel('Expenses (₹1000s)')
plt.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Sample data
months = ['Jan', 'Feb', 'Mar', 'Apr']
sales = [100, 150, 130, 170]
expenses = [80, 90, 85, 95]

# Create 1 row, 2 columns of subplots
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# Subplot 1: Line chart (Sales)
ax[0].plot(months, sales, marker='o', color='#45B7D1', linewidth=2)
ax[0].set_title('Monthly Sales', fontsize=14, fontweight='bold')
ax[0].set_xlabel('Month')
ax[0].set_ylabel('Sales (₹1000s)')
ax[0].grid(True, alpha=0.3)

# Subplot 2: Bar chart (Expenses)
ax[1].bar(months, expenses, color='#FF6B6B', alpha=0.7)
ax[1].set_title('Monthly Expenses', fontsize=14, fontweight='bold')
ax[1].set_xlabel('Month')
ax[1].set_ylabel('Expenses (₹1000s)')
ax[1].grid(axis='y', alpha=0.3)

fig.suptitle('Comparison of Monthly Sales vs Expenses')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 💾 Saving Figures - Complete Guide
#
# ## What is `savefig()`?
#
# **`savefig()`** saves your matplotlib charts as image files instead of just displaying them. This allows you to use charts in reports, presentations, websites, or share them with others.
#
# **Simple Rule:** Create once, save forever 📸
#
# ---
#
# ## 🎯 Why Save Figures?
#
# ### Use Cases
#
# | Scenario | Benefit |
# |----------|---------|
# | **Reports & Documents** | Insert charts into Word/PDF documents |
# | **Presentations** | Add visualizations to PowerPoint slides |
# | **Websites & Blogs** | Display charts on web pages |
# | **Email & Sharing** | Send analysis results to colleagues |
# | **Archiving** | Keep records of analysis over time |
# | **Publications** | Submit high-quality charts for papers |
#
# **Problem:** `plt.show()` only displays, doesn't save
# **Solution:** Use `plt.savefig()` to export as files
#
# ---
#
# ## 🔧 Syntax Breakdown
#
# ```python
# plt.savefig(filename, dpi, format, bbox_inches, transparent, facecolor, pad_inches)
# ```
#
# ### Parameters Explained
#
# | Parameter | Type | Required | Description | Example |
# |-----------|------|----------|-------------|---------|
# | `filename` | string | ✅ **Yes** | File path with extension | `'sales_chart.png'` |
# | `dpi` | int | ❌ No | Resolution (dots per inch, default: 100) | `300` (high quality) |
# | `format` | string | ❌ No | File format (auto-detected from filename) | `'png'`, `'pdf'`, `'svg'` |
# | `bbox_inches` | string | ❌ No | Bounding box (default: None) | `'tight'` (removes whitespace) |
# | `transparent` | bool | ❌ No | Transparent background (default: False) | `True` (no white background) |
# | `facecolor` | string | ❌ No | Background color (default: 'white') | `'#f0f0f0'`, `'lightgray'` |
# | `pad_inches` | float | ❌ No | Padding around figure (default: 0.1) | `0.2` (more padding) |
#
# ---
#
# ## 📁 Supported File Formats
#
# ### Common Formats
#
# | Format | Extension | Best For | Quality |
# |--------|-----------|----------|---------|
# | **PNG** | `.png` | Web, presentations, general use | Good (raster) |
# | **JPG/JPEG** | `.jpg`, `.jpeg` | Photos, compressed images | Medium (raster) |
# | **PDF** | `.pdf` | Documents, printing, reports | Excellent (vector) |
# | **SVG** | `.svg` | Web, scalable graphics | Excellent (vector) |
# | **EPS** | `.eps` | Publications, professional printing | Excellent (vector) |
# | **TIFF** | `.tiff`, `.tif` | High-quality printing | Excellent (raster) |
#
# **Raster vs Vector:**
# - **Raster (PNG, JPG):** Pixels - quality degrades when zoomed
# - **Vector (PDF, SVG, EPS):** Shapes - perfect at any zoom level
#
# ---
#
# ## 💻 Basic Usage Examples
#
# ### Example 1: Simple Save (PNG)
#
# ```python
# import matplotlib.pyplot as plt
#
# # Create chart
# months = ['Jan', 'Feb', 'Mar', 'Apr']
# sales = [100, 150, 130, 170]
#
# plt.plot(months, sales, marker='o')
# plt.title('Monthly Sales')
# plt.xlabel('Month')
# plt.ylabel('Sales (₹1000s)')
# plt.grid(True, alpha=0.3)
#
# # Save as PNG
# plt.savefig('sales_chart.png')
# plt.show()
# ```
#
# **Result:** Creates `sales_chart.png` in current directory
#
# ---
#
# ### Example 2: High-Quality Save (PDF)
#
# ```python
# # Save as high-resolution PDF (for printing)
# plt.savefig('sales_chart.pdf', dpi=300, bbox_inches='tight')
# plt.show()
# ```
#
# **Best for:** Reports, publications, professional documents
#
# ---
#
# ### Example 3: Transparent Background
#
# ```python
# # Save with transparent background (for presentations)
# plt.savefig('sales_chart.png', transparent=True, bbox_inches='tight')
# plt.show()
# ```
#
# **Best for:** PowerPoint slides, overlaying on other images
#
# ---
#
# ### Example 4: Custom Path
#
# ```python
# # Save in specific folder with custom settings
# plt.savefig('outputs/reports/sales_2024.png',
#             dpi=300,
#             bbox_inches='tight',
#             facecolor='white',
#             pad_inches=0.2)
# plt.show()
# ```
#
# **Note:** Folder must exist before saving
#
# ---
#
# ## 📊 Understanding `dpi` (Resolution)
#
# **DPI** = Dots Per Inch (higher = better quality, larger file)
#
# | DPI Value | Quality | Use Case | File Size |
# |-----------|---------|----------|-----------|
# | `72` | Low | Web preview | Small |
# | `100` | Standard (default) | Screen display | Medium |
# | `150` | Good | General presentations | Medium |
# | `300` | High | Printing, publications | Large |
# | `600` | Very High | Professional printing | Very Large |
#
# **Recommendation:**
# - **Web/Screen:** `dpi=100-150`
# - **Presentations:** `dpi=150-200`
# - **Printing:** `dpi=300`
# - **Publications:** `dpi=300-600`
#
# ---
#
# ## 🎨 Understanding `bbox_inches='tight'`
#
# ### Without `bbox_inches='tight'`
#
# ```
# ┌────────────────────────┐
# │  ⬜⬜⬜⬜⬜⬜⬜⬜⬜    │
# │  ⬜      Chart      ⬜  │
# │  ⬜                 ⬜  │
# │  ⬜⬜⬜⬜⬜⬜⬜⬜⬜    │
# └────────────────────────┘
#   ❌ Extra white space
# ```
#
# ### With `bbox_inches='tight'`
#
# ```
# ┌──────────────┐
# │    Chart     │
# │              │
# └──────────────┘
#   ✅ No wasted space
# ```
#
# **Always use** `bbox_inches='tight'` for cleaner exports!
#
# ---
#
# ## 🔄 Complete Professional Example
#
# ```python
# import matplotlib.pyplot as plt
#
# # Data
# months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
# sales = [100, 150, 130, 170, 160, 190]
# expenses = [80, 90, 85, 95, 88, 100]
#
# # Create figure
# fig, ax = plt.subplots(figsize=(10, 6))
#
# # Plot data
# ax.plot(months, sales, marker='o', label='Sales', linewidth=2, color='#45B7D1')
# ax.plot(months, expenses, marker='s', label='Expenses', linewidth=2, color='#FF6B6B')
#
# # Styling
# ax.set_title('Monthly Sales vs Expenses', fontsize=16, fontweight='bold')
# ax.set_xlabel('Month', fontsize=12)
# ax.set_ylabel('Amount (₹1000s)', fontsize=12)
# ax.legend(fontsize=11)
# ax.grid(True, alpha=0.3)
#
# # Save in multiple formats
# plt.savefig('sales_analysis.png', dpi=300, bbox_inches='tight')        # For web
# plt.savefig('sales_analysis.pdf', dpi=300, bbox_inches='tight')        # For printing
# plt.savefig('sales_analysis_trans.png', transparent=True, dpi=150, bbox_inches='tight')  # For presentations
#
# plt.show()
# ```
#
# **Output:** 3 files created with different formats and settings
#
# ---
#
# ## 📋 Format Selection Guide
#
# | Your Need | Recommended Format | Settings |
# |-----------|-------------------|----------|
# | **Quick sharing** | PNG | `dpi=150, bbox_inches='tight'` |
# | **Web/Blog** | PNG | `dpi=100-150, transparent=True` |
# | **PowerPoint** | PNG | `transparent=True, dpi=150` |
# | **Word Document** | PNG/PDF | `dpi=300, bbox_inches='tight'` |
# | **Research Paper** | PDF/EPS | `dpi=300-600, bbox_inches='tight'` |
# | **Printing** | PDF/TIFF | `dpi=300, bbox_inches='tight'` |
# | **Website (scalable)** | SVG | `bbox_inches='tight'` |
#
# ---
#
# ## ⚠️ Best Practices
#
# ✅ **Always use** `bbox_inches='tight'` to remove extra whitespace
# ✅ Save **before** `plt.show()` or use `plt.savefig()` before closing figure
# ✅ Use **PNG** for general use, **PDF** for documents, **SVG** for web
# ✅ Set `dpi=300` for high-quality prints
# ✅ Use descriptive filenames: `sales_2024_Q1.png` not `chart1.png`
# ✅ Create output folders to organize saved figures
# ✅ Use `transparent=True` for presentations to blend with slide backgrounds
# ❌ Don't use low DPI (<100) for printing - will look pixelated
# ❌ Don't forget file extension - it determines the format
# ❌ Don't save after `plt.show()` in scripts - figure may close
#
# ---
#
# ## 💡 Pro Tips
#
# ### Tip 1: Save Multiple Versions
#
# ```python
# # Save for different purposes
# formats = ['png', 'pdf', 'svg']
# for fmt in formats:
#     plt.savefig(f'chart.{fmt}', dpi=300, bbox_inches='tight')
# ```
#
# ### Tip 2: Timestamp Filenames
#
# ```python
# from datetime import datetime
#
# timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
# plt.savefig(f'sales_chart_{timestamp}.png', dpi=300, bbox_inches='tight')
# ```
#
# ### Tip 3: Verify File Creation
#
# ```python
# import os
#
# filename = 'sales_chart.png'
# plt.savefig(filename, dpi=300, bbox_inches='tight')
#
# if os.path.exists(filename):
#     print(f"✅ Chart saved successfully: {filename}")
# else:
#     print(f"❌ Failed to save chart")
# ```

# %%
# Data
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
sales = [100, 150, 130, 170, 160, 190]
expenses = [80, 90, 85, 95, 88, 100]

# Create figure
fig, ax = plt.subplots(figsize=(10, 6))

# Plot data
ax.plot(months, sales, marker='o', label='Sales', linewidth=2, color='#45B7D1')
ax.plot(months, expenses, marker='s', label='Expenses', linewidth=2, color='#FF6B6B')

# Styling
ax.set_title('Monthly Sales vs Expenses', fontsize=16, fontweight='bold')
ax.set_xlabel('Month', fontsize=12)
ax.set_ylabel('Amount (₹1000s)', fontsize=12)
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3)

# Save in multiple formats
plt.savefig('sales_analysis.png', dpi=300, bbox_inches='tight')        # For web
plt.savefig('sales_analysis.pdf', dpi=300, bbox_inches='tight')        # For printing
plt.savefig('sales_analysis_trans.png', transparent=True, dpi=150, bbox_inches='tight')  # For presentations

plt.show()

# %% [markdown]
# # 🎯 Understanding Subplots - Simplified Guide
#
# ## The Canvas Concept
#
# Think of matplotlib as a **canvas** where you paint charts. Subplots let you divide this canvas into **sections** to paint multiple charts.
#
# ```
# Single Plot (Normal):           Subplots (Divided Canvas):
# ┌─────────────────┐            ┌─────────┬─────────┐
# │                 │            │ Chart 1 │ Chart 2 │
# │   One Chart     │            │         │         │
# │                 │            │         │         │
# └─────────────────┘            └─────────┴─────────┘
#   1 Canvas, 1 Chart              1 Canvas, 2 Charts
# ```
#
# ---
#
# ## 🔢 Understanding Positions & Indexing
#
# ### The Grid System
#
# When you create subplots, you're creating a **grid** (like a table). Each cell in the grid holds one chart.
#
# #### Example: 1 Row, 2 Columns Grid
#
# ```python
# fig, ax = plt.subplots(1, 2)
# ```
#
# **What this creates:**
# ```
#      Column 0      Column 1
#     ┌─────────┬─────────┐
# Row 0│  ax[0]  │  ax[1]  │
#     └─────────┴─────────┘
# ```
#
# **Index counting:**
# - Starts from **0** (not 1!)
# - Goes **left to right**
# - `ax[0]` = first position (left)
# - `ax[1]` = second position (right)
#
# ---
#
# #### Example: 2 Rows, 1 Column Grid
#
# ```python
# fig, ax = plt.subplots(2, 1)
# ```
#
# **What this creates:**
# ```
#       Column 0
#     ┌─────────┐
# Row 0│  ax[0]  │  ← Top
#     ├─────────┤
# Row 1│  ax[1]  │  ← Bottom
#     └─────────┘
# ```
#
# **Index counting:**
# - `ax[0]` = top position
# - `ax[1]` = bottom position
#
# ---
#
# #### Example: 2 Rows, 2 Columns Grid
#
# ```python
# fig, ax = plt.subplots(2, 2)
# ```
#
# **What this creates:**
# ```
#         Column 0      Column 1
#     ┌───────────┬───────────┐
# Row 0│  ax[0,0]  │  ax[0,1]  │  ← First row
#     ├───────────┼───────────┤
# Row 1│  ax[1,0]  │  ax[1,1]  │  ← Second row
#     └───────────┴───────────┘
# ```
#
# **Index counting (2D):**
# - `ax[row, column]` format
# - `ax[0,0]` = top-left
# - `ax[0,1]` = top-right
# - `ax[1,0]` = bottom-left
# - `ax[1,1]` = bottom-right
#
# ---
#
# ## 🎨 What is `ax`?
#
# **`ax`** (short for "axes") is a **container** that holds your subplot charts.
#
# **Think of it like:**
# ```
# fig = The entire canvas (frame)
# ax  = Individual painting spots on the canvas
# ```
#
# ### Single Row/Column: `ax` is a 1D list
#
# ```python
# fig, ax = plt.subplots(1, 3)  # 1 row, 3 columns
# ```
#
# Access like a list:
# - `ax[0]` = first subplot
# - `ax[1]` = second subplot
# - `ax[2]` = third subplot
#
# ### Multiple Rows & Columns: `ax` is a 2D array
#
# ```python
# fig, ax = plt.subplots(2, 2)  # 2 rows, 2 columns
# ```
#
# Access like a table:
# - `ax[0, 0]` = row 0, column 0
# - `ax[0, 1]` = row 0, column 1
# - `ax[1, 0]` = row 1, column 0
# - `ax[1, 1]` = row 1, column 1
#
# ---
#
# ## 💻 Complete Example: 2 Plots Side-by-Side
#
# ### Step-by-Step Breakdown
#
# ```python
# import matplotlib.pyplot as plt
#
# # Step 1: Prepare data
# months = ['Jan', 'Feb', 'Mar', 'Apr']
# sales = [100, 150, 130, 170]
# expenses = [80, 90, 85, 95]
#
# # Step 2: Create canvas with 1 row, 2 columns
# fig, ax = plt.subplots(1, 2, figsize=(12, 5))
# #   fig = entire canvas
# #   ax  = list with 2 positions [ax[0], ax[1]]
#
# # Step 3: Plot in FIRST position (ax[0])
# ax[0].plot(months, sales, marker='o', color='#45B7D1')
# ax[0].set_title('Sales Trend')
# ax[0].set_xlabel('Month')
# ax[0].set_ylabel('Sales (₹1000s)')
# ax[0].grid(True, alpha=0.3)
#
# # Step 4: Plot in SECOND position (ax[1])
# ax[1].bar(months, expenses, color='#FF6B6B', alpha=0.7)
# ax[1].set_title('Monthly Expenses')
# ax[1].set_xlabel('Month')
# ax[1].set_ylabel('Expenses (₹1000s)')
# ax[1].grid(axis='y', alpha=0.3)
#
# # Step 5: Adjust layout and show
# plt.tight_layout()
# plt.show()
# ```
#
# **Visual Result:**
# ```
# ┌─────────────────────┬─────────────────────┐
# │   Sales Trend       │  Monthly Expenses   │
# │   (Line Chart)      │   (Bar Chart)       │
# │                     │                     │
# │   ax[0].plot(...)   │   ax[1].bar(...)    │
# └─────────────────────┴─────────────────────┘
#        Position 0             Position 1
# ```
#
# ---
#
# ## 💻 Complete Example: 2×2 Grid (4 Plots)
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Data
# x = np.linspace(0, 10, 50)
# y1 = x
# y2 = x ** 2
# y3 = np.sin(x)
# y4 = np.cos(x)
#
# # Create 2x2 grid
# fig, ax = plt.subplots(2, 2, figsize=(12, 10))
#
# # Top-left: ax[0, 0]
# ax[0, 0].plot(x, y1, color='blue')
# ax[0, 0].set_title('Linear (y = x)')
# ax[0, 0].grid(True, alpha=0.3)
#
# # Top-right: ax[0, 1]
# ax[0, 1].plot(x, y2, color='green')
# ax[0, 1].set_title('Quadratic (y = x²)')
# ax[0, 1].grid(True, alpha=0.3)
#
# # Bottom-left: ax[1, 0]
# ax[1, 0].plot(x, y3, color='red')
# ax[1, 0].set_title('Sine Wave')
# ax[1, 0].grid(True, alpha=0.3)
#
# # Bottom-right: ax[1, 1]
# ax[1, 1].plot(x, y4, color='orange')
# ax[1, 1].set_title('Cosine Wave')
# ax[1, 1].grid(True, alpha=0.3)
#
# plt.tight_layout()
# plt.show()
# ```
#
# **Visual Result:**
# ```
# ┌────────────────┬────────────────┐
# │  Linear (y=x)  │ Quadratic (y²) │
# │   ax[0, 0]     │   ax[0, 1]     │  ← Row 0
# ├────────────────┼────────────────┤
# │  Sine Wave     │  Cosine Wave   │
# │   ax[1, 0]     │   ax[1, 1]     │  ← Row 1
# └────────────────┴────────────────┘
#     Column 0         Column 1
# ```
#
# ---
#
# ## 🔄 Before vs After: Understanding the Difference
#
# ### Without Subplots (Separate Charts)
#
# ```python
# # First chart
# plt.plot(months, sales)
# plt.title('Sales')
# plt.show()  # Shows, then closes
#
# # Second chart
# plt.bar(months, expenses)
# plt.title('Expenses')
# plt.show()  # Shows in new window
# ```
#
# **Result:** Two separate windows, hard to compare
#
# ---
#
# ### With Subplots (Together)
#
# ```python
# fig, ax = plt.subplots(1, 2)
#
# # Both charts in same window
# ax[0].plot(months, sales)
# ax[0].set_title('Sales')
#
# ax[1].bar(months, expenses)
# ax[1].set_title('Expenses')
#
# plt.tight_layout()
# plt.show()  # Shows BOTH together
# ```
#
# **Result:** One window, easy side-by-side comparison
#
# ---
#
# ## 📊 Common Patterns Cheat Sheet
#
# ### Pattern 1: Side-by-Side (Horizontal)
#
# ```python
# fig, ax = plt.subplots(1, 2)  # 1 row, 2 cols
# ax[0].plot(...)   # Left chart
# ax[1].bar(...)    # Right chart
# ```
#
# ---
#
# ### Pattern 2: Stacked (Vertical)
#
# ```python
# fig, ax = plt.subplots(2, 1)  # 2 rows, 1 col
# ax[0].plot(...)   # Top chart
# ax[1].bar(...)    # Bottom chart
# ```
#
# ---
#
# ### Pattern 3: 2×2 Grid
#
# ```python
# fig, ax = plt.subplots(2, 2)  # 2 rows, 2 cols
# ax[0, 0].plot(...)   # Top-left
# ax[0, 1].bar(...)    # Top-right
# ax[1, 0].scatter(...) # Bottom-left
# ax[1, 1].hist(...)    # Bottom-right
# ```
#
# ---
#
# ### Pattern 4: 3 in a Row
#
# ```python
# fig, ax = plt.subplots(1, 3)  # 1 row, 3 cols
# ax[0].plot(...)    # First
# ax[1].bar(...)     # Second
# ax[2].scatter(...) # Third
# ```
#
# ---
#
# ## 🎯 Key Methods for Each Subplot
#
# Instead of using `plt.something()`, use `ax[position].something()`:
#
# | Regular Plot | With Subplots |
# |--------------|---------------|
# | `plt.plot(x, y)` | `ax[0].plot(x, y)` |
# | `plt.bar(x, y)` | `ax[1].bar(x, y)` |
# | `plt.scatter(x, y)` | `ax[0, 0].scatter(x, y)` |
# | `plt.hist(data)` | `ax[0, 1].hist(data)` |
# | `plt.title('Title')` | `ax[0].set_title('Title')` |
# | `plt.xlabel('X')` | `ax[0].set_xlabel('X')` |
# | `plt.ylabel('Y')` | `ax[0].set_ylabel('Y')` |
# | `plt.legend()` | `ax[0].legend()` |
# | `plt.grid(True)` | `ax[0].grid(True)` |
#
# **Notice:** `plt.something()` becomes `ax[position].something()` (add `set_` for labels/title)
#
# ---
#
# ## 🧠 Mental Model
#
# **Think of subplots like apartment building:**
#
# ```
# Building (fig) = Entire structure
# Apartments (ax) = Individual units
#
# 1 Row, 3 Cols = Ground floor with 3 apartments
#     ax[0]    ax[1]    ax[2]
#
# 2 Rows, 2 Cols = 2 floors, 2 apartments each
#     Floor 1: ax[0,0]  ax[0,1]
#     Floor 0: ax[1,0]  ax[1,1]
# ```
#
# Each apartment (subplot) has its own chart, but they're all in the same building (canvas)!
#
# ---
#
# ## ⚠️ Common Mistakes & Solutions
#
# ### Mistake 1: Using `plt` instead of `ax`
#
# ```python
# # ❌ Wrong
# fig, ax = plt.subplots(1, 2)
# plt.plot(x, y)  # Will plot in last active subplot only!
#
# # ✅ Correct
# fig, ax = plt.subplots(1, 2)
# ax[0].plot(x, y)  # Plots in specific subplot
# ```
#
# ---
#
# ### Mistake 2: Wrong index for 2D grid
#
# ```python
# fig, ax = plt.subplots(2, 2)
#
# # ❌ Wrong
# ax[0].plot(x, y)  # Error! Need 2 indices
#
# # ✅ Correct
# ax[0, 0].plot(x, y)  # row, column
# ```
#
# ---
#
# ### Mistake 3: Forgetting `tight_layout()`
#
# ```python
# # ❌ Without tight_layout
# fig, ax = plt.subplots(1, 2)
# ax[0].plot(x, y)
# ax[1].bar(x, y)
# plt.show()  # Overlapping titles/labels!
#
# # ✅ With tight_layout
# fig, ax = plt.subplots(1, 2)
# ax[0].plot(x, y)
# ax[1].bar(x, y)
# plt.tight_layout()  # Clean spacing!
# plt.show()
# ```
#
# ---
#
# ## 💡 Quick Reference Table
#
# | Grid | Code | Access Method | Positions |
# |------|------|---------------|-----------|
# | 1×2 | `subplots(1, 2)` | `ax[0]`, `ax[1]` | Left, Right |
# | 2×1 | `subplots(2, 1)` | `ax[0]`, `ax[1]` | Top, Bottom |
# | 1×3 | `subplots(1, 3)` | `ax[0]`, `ax[1]`, `ax[2]` | Left, Middle, Right |
# | 2×2 | `subplots(2, 2)` | `ax[0,0]`, `ax[0,1]`, `ax[1,0]`, `ax[1,1]` | TL, TR, BL, BR |
# | 3×2 | `subplots(3, 2)` | `ax[row, col]` (row: 0-2, col: 0-1) | 6 positions |
#
# ---
#
# ## 🎓 Practice Exercise
#
# **Try this yourself:**
#
# ```python
# import matplotlib.pyplot as plt
#
# # Create 1 row, 3 columns
# fig, ax = plt.subplots(1, 3, figsize=(15, 5))
#
# # Chart 1: Line
# ax[0].plot([1,2,3], [10,20,15], marker='o')
# ax[0].set_title('Line Chart')
#
# # Chart 2: Bar
# ax[1].bar(['A','B','C'], [30,40,35])
# ax[1].set_title('Bar Chart')
#
# # Chart 3: Scatter
# ax[2].scatter([1,2,3], [25,35,30])
# ax[2].set_title('Scatter Plot')
#
# plt.tight_layout()
# plt.show()
# ```
#
# **Expected Output:** 3 charts side-by-side in one window!
#
# ---
#
# ## ✅ Summary
#
# 1. **`fig, ax = plt.subplots(rows, cols)`** creates a grid of subplots
# 2. **`ax[position]`** accesses each subplot (starts from 0)
# 3. **1D grids** use `ax[0]`, `ax[1]`, etc.
# 4. **2D grids** use `ax[row, col]` like `ax[0, 0]`, `ax[0, 1]`
# 5. **Use `ax[position].method()`** instead of `plt.method()`
# 6. **Always call `plt.tight_layout()`** before `plt.show()`
#
# **Remember:** Multiple plots, one canvas, organized in a grid! 🎨

# %%
# Data
x = np.linspace(0, 10, 50)
y1 = x
y2 = x ** 2
y3 = np.sin(x)
y4 = np.cos(x)

# Create 2x2 grid
fig, ax = plt.subplots(2, 2, figsize=(12, 10))

# Top-left: ax[0, 0]
ax[0, 0].plot(x, y1, color='blue')
ax[0, 0].set_title('Linear (y = x)')
ax[0, 0].grid(True, alpha=0.3)

# Top-right: ax[0, 1]
ax[0, 1].plot(x, y2, color='green')
ax[0, 1].set_title('Quadratic (y = x²)')
ax[0, 1].grid(True, alpha=0.3)

# Bottom-left: ax[1, 0]
ax[1, 0].plot(x, y3, color='red')
ax[1, 0].set_title('Sine Wave')
ax[1, 0].grid(True, alpha=0.3)

# Bottom-right: ax[1, 1]
ax[1, 1].plot(x, y4, color='orange')
ax[1, 1].set_title('Cosine Wave')
ax[1, 1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
