# %% [markdown]
# # 🌐 Web Scraping
# ### 🎯 Ambition Box Data
#
# ---
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h4 style="color: white; margin: 0;">📦 Required Libraries</h4>
# </div>
#
# ```python
# import pandas as pd           # Data manipulation & analysis
# import requests               # HTTP requests
# from bs4 import BeautifulSoup # Web scraping powerhouse 🚀
# import numpy as np            # Numerical computing
# ```
#
# ### 📚 Library Overview
#
# | Library | Purpose | Key Features |
# |---------|---------|--------------|
# | **pandas** | Data Analysis | DataFrames, CSV handling, data manipulation |
# | **requests** | HTTP Requests | GET/POST requests, API calls |
# | **BeautifulSoup** | Web Scraping | HTML parsing, element extraction |
# | **numpy** | Numerical Computing | Arrays, mathematical operations |
#
# ---

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
requests.get('https://www.carwale.com/new/best-cars-under-30-lakh').text
# Out:
# '\n\n<!DOCTYPE html><html lang="en" itemscope itemtype="http://schema.org/WebPage"\n\tprefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#"><head><meta charset="utf-8" /><meta name="theme-color" content="#0e3a50"><meta name="robots" content="max-snippet:-1, max-image-preview:large" />\n\t<title data-react-helmet="true" itemprop="name">Best Cars Under 30 Lakh in India| Top Cars Below 30 Lakh - CarWale</title>\n\t\n<link href="https://imgd.aeplcdn.com" rel="preconnect dns-prefetch" crossorigin><link href="https://stc.aeplcdn.com" rel="preconnect dns-prefetch" crossorigin><link href="https://www.googletagmanager.com" rel="preconnect dns-prefetch" crossorigin><link href="https://www.googletagservices.com" rel="preconnect dns-prefetch" crossorigin><link href="https://bid.g.doubleclick.net" rel="preconnect dns-prefetch" crossorigin><link href="https://pagead2.googlesyndication.com" rel="dns-prefetch" crossorigin><link href="https://googleads.g.doubleclick.net" rel="dns-prefetch" crossorigin><link href="https://tpc.googlesyndication.com" rel="dns-prefetch" crossorigin><link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch" crossorigin><link href="https://adservice.google.co.in" rel="dns-prefetch" crossorigin><link href="https://stats.g.doubleclick.net" rel="dns-prefetch" crossorigin><link href="https://www.google-analytics.com" rel="dns-prefetch" crossorigin><link href="https://www.googleadservices.com" rel="dns-prefetch" crossorigin><link href="https://connect.facebook.net" rel="dns-prefetch" crossorigin><link href="https://s3.amazonaws.com" rel="dns-prefetch" crossorigin><link href="https://ap-sonar.sociomantic.com" rel="dns-prefetch" crossorigin><link href="https://api.survicate.com" rel="dns-prefetch" crossorigin><link href="https://survey.survicate.com" rel="dns-prefetch" crossorigin><link href="https://sb.scorecardresearch.com" rel="dns-prefetch" crossorigin><link href="https://www.google.com" rel="dns-prefetch" crossorigin><link href="https://www.google.co.in" rel="dns-prefetch" crossorigin><link href="https://ampcid.google.com" rel="dns-prefetch" crossorigin><link href="https://ampcid.google.co.in" rel="dns-prefetch" crossorigin><link href="https://surveys-static.survicate.com" rel="dns-prefetch" crossorigin>\n\t<link rel="preload" href="https://stc.aeplcdn.com/fonts/lato-bold.woff2" as="font" type="font/woff2" crossorigin><link rel="preload" href="https://stc.aeplcdn.com/fonts/lato-regular.woff2" as="font" type="font/woff2" crossorigin><link rel="preload" href="" as="image" />\n\t\n\t<link data-chunk="main-desktop" rel="preload" as="style" href="https://stc.aeplcdn.com/staticminv2/css/main-desktop.735b0ace0.css">\n\n\t\n\t<link data-react-helmet="true" rel="manifest" href="/manifest.webmanifest.json?v=1"/><link data-react-helmet="true" rel="canonical" href="https://www.carwale.com/new/best-cars-under-30-lakh/"/><link data-react-helmet="true" rel="alternate" href="https://www.carwale.com/new/best-cars-under-30-lakh/"/><link data-react-helmet="true" rel="alternate" hrefLang="en" href="https://www.carwale.com/new/best-cars-under-30-lakh/"/><link data-react-helmet="true" rel="alternate" hrefLang="hi" href="https://www.carwale.com/hi/new/best-cars-under-30-lakh/"/><link data-react-helmet="true" rel="alternate" hrefLang="x-default" href="https://www.carwale.com/new/best-cars-under-30-lakh/"/><link data-react-helmet="true" rel="next" href="/new/best-cars-under-30-lakh/2/"/><link data-react-helmet="true" rel="preload" href="https://imgd.aeplcdn.com/227x128/n/cw/ec/47051/compass-exterior-right-front-three-quarter-83.jpeg?isig=0&amp;q=80" as="image"/><link data-react-helmet="true" rel="preload" href="https://imgd.aeplcdn.com/227x128/n/cw/ec/106815/creta-exterior-right-front-three-quarter-6.png?isig=0&amp;q=80" as="image"/><link data-react-helmet="true" rel="preload" href="https://imgd.aeplcdn.com/227x128/n/cw/ec/194921/victoris-exterior-right-front-three-quarter-8.png?isig=0&amp;q=80" as="image"/><link data-react-helm ...

# %% [markdown]
# ### 🚫 Understanding 403 Access Denied Error
# ```python
# requests.get('https://www.carwale.com/new/best-cars-under-30-lakh').text
# ```
#
# ---
#
# ### ❌ Why Do We Get 403 Error?
#
# **Simple Reasons:**
#
# - 🤖 **Website thinks you're a bot** - Your request doesn't look like it's from a real browser
# - 🚨 **Missing identification** - No User-Agent header to identify what's making the request
# - 🛡️ **Security protection** - Websites block automated scripts to prevent abuse
# - 👤 **Looks suspicious** - Python requests look different from human browser requests
# - 🔒 **Anti-scraping measures** - Sites want to control who accesses their data
#
# ---
#
# ### 🎭 The Solution: Add Headers
#
# **Make your request look human!**
# ```python
# headers = {
#     'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'
# }
#
# requests.get('https://www.carwale.com/new/best-cars-under-30-lakh', headers=headers).text
# ```
#
# ---
#
# ### 💡 Key Takeaway
#
# **Without headers** = 🤖 "I'm a bot!"
# **With headers** = 👤 "I'm a regular Chrome browser user!"
#
# ---

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'
}

webpage = requests.get('https://www.carwale.com/new/best-cars-under-30-lakh', headers=headers).text
webpage
# Out:
# '\n\n<!DOCTYPE html><html lang="en" itemscope itemtype="http://schema.org/WebPage"\n\tprefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#"><head><meta charset="utf-8" /><meta name="theme-color" content="#0e3a50"><meta name="robots" content="max-snippet:-1, max-image-preview:large" />\n\t<title data-react-helmet="true" itemprop="name">Best Cars Under 30 Lakh in India| Top Cars Below 30 Lakh - CarWale</title>\n\t\n<link href="https://imgd.aeplcdn.com" rel="preconnect dns-prefetch" crossorigin><link href="https://stc.aeplcdn.com" rel="preconnect dns-prefetch" crossorigin><link href="https://www.googletagmanager.com" rel="preconnect dns-prefetch" crossorigin><link href="https://www.googletagservices.com" rel="preconnect dns-prefetch" crossorigin><link href="https://bid.g.doubleclick.net" rel="preconnect dns-prefetch" crossorigin><link href="https://pagead2.googlesyndication.com" rel="dns-prefetch" crossorigin><link href="https://googleads.g.doubleclick.net" rel="dns-prefetch" crossorigin><link href="https://tpc.googlesyndication.com" rel="dns-prefetch" crossorigin><link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch" crossorigin><link href="https://adservice.google.co.in" rel="dns-prefetch" crossorigin><link href="https://stats.g.doubleclick.net" rel="dns-prefetch" crossorigin><link href="https://www.google-analytics.com" rel="dns-prefetch" crossorigin><link href="https://www.googleadservices.com" rel="dns-prefetch" crossorigin><link href="https://connect.facebook.net" rel="dns-prefetch" crossorigin><link href="https://s3.amazonaws.com" rel="dns-prefetch" crossorigin><link href="https://ap-sonar.sociomantic.com" rel="dns-prefetch" crossorigin><link href="https://api.survicate.com" rel="dns-prefetch" crossorigin><link href="https://survey.survicate.com" rel="dns-prefetch" crossorigin><link href="https://sb.scorecardresearch.com" rel="dns-prefetch" crossorigin><link href="https://www.google.com" rel="dns-prefetch" crossorigin><link href="https://www.google.co.in" rel="dns-prefetch" crossorigin><link href="https://ampcid.google.com" rel="dns-prefetch" crossorigin><link href="https://ampcid.google.co.in" rel="dns-prefetch" crossorigin><link href="https://surveys-static.survicate.com" rel="dns-prefetch" crossorigin>\n\t<link rel="preload" href="https://stc.aeplcdn.com/fonts/lato-bold.woff2" as="font" type="font/woff2" crossorigin><link rel="preload" href="https://stc.aeplcdn.com/fonts/lato-regular.woff2" as="font" type="font/woff2" crossorigin><link rel="preload" href="" as="image" />\n\t\n\t<link data-chunk="main-desktop" rel="preload" as="style" href="https://stc.aeplcdn.com/staticminv2/css/main-desktop.735b0ace0.css">\n\n\t\n\t<link data-react-helmet="true" rel="manifest" href="/manifest.webmanifest.json?v=1"/><link data-react-helmet="true" rel="canonical" href="https://www.carwale.com/new/best-cars-under-30-lakh/"/><link data-react-helmet="true" rel="alternate" href="https://www.carwale.com/new/best-cars-under-30-lakh/"/><link data-react-helmet="true" rel="alternate" hrefLang="en" href="https://www.carwale.com/new/best-cars-under-30-lakh/"/><link data-react-helmet="true" rel="alternate" hrefLang="hi" href="https://www.carwale.com/hi/new/best-cars-under-30-lakh/"/><link data-react-helmet="true" rel="alternate" hrefLang="x-default" href="https://www.carwale.com/new/best-cars-under-30-lakh/"/><link data-react-helmet="true" rel="next" href="/new/best-cars-under-30-lakh/2/"/><link data-react-helmet="true" rel="preload" href="https://imgd.aeplcdn.com/227x128/n/cw/ec/47051/compass-exterior-right-front-three-quarter-83.jpeg?isig=0&amp;q=80" as="image"/><link data-react-helmet="true" rel="preload" href="https://imgd.aeplcdn.com/227x128/n/cw/ec/106815/creta-exterior-right-front-three-quarter-6.png?isig=0&amp;q=80" as="image"/><link data-react-helmet="true" rel="preload" href="https://imgd.aeplcdn.com/227x128/n/cw/ec/194921/victoris-exterior-right-front-three-quarter-8.png?isig=0&amp;q=80" as="image"/><link data-react-helm ...

# %% [markdown]
# ### 🍲 Creating BeautifulSoup Object
# ```python
# soup = BeautifulSoup(webpage, 'lxml')
# soup
# ```
#
# ---
#
# ### 🤔 What is Soup?
#
# **Simple Explanation:**
#
# - 📄 **Soup = Organized HTML** - Takes messy HTML text and structures it
# - 🔍 **Searchable Document** - Makes HTML easy to search and navigate
# - 🎯 **Data Extractor** - Helps you find specific elements (tags, classes, IDs)
# - 🧩 **Parser Object** - Breaks down HTML into understandable parts
# - 🛠️ **Scraping Tool** - Your main tool for extracting data from web pages
#
# ---
#
# ### 🔧 Breaking Down the Code
#
# | Component | What It Does |
# |-----------|--------------|
# | `BeautifulSoup()` | Function that creates the soup object |
# | `webpage` | Raw HTML text from the website |
# | `'lxml'` | Parser that reads and structures the HTML |
# | `soup` | Final object you can search and extract data from |
#
# ---
#
# ### 💡 Think of Soup Like This:
#
# **Raw HTML (webpage)** = 📦 Messy box of ingredients
# **BeautifulSoup (soup)** = 🍲 Organized, ready-to-use meal
#
# Now you can easily "pick out" the data you need! 🎯
#
# ---

# %%
soup = BeautifulSoup(webpage, 'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#"><head><meta charset="utf-8"/><meta content="#0e3a50" name="theme-color"/><meta content="max-snippet:-1, max-image-preview:large" name="robots"/>
# <title data-react-helmet="true" itemprop="name">Best Cars Under 30 Lakh in India| Top Cars Below 30 Lakh - CarWale</title>
# <link crossorigin="" href="https://imgd.aeplcdn.com" rel="preconnect dns-prefetch"/><link crossorigin="" href="https://stc.aeplcdn.com" rel="preconnect dns-prefetch"/><link crossorigin="" href="https://www.googletagmanager.com" rel="preconnect dns-prefetch"/><link crossorigin="" href="https://www.googletagservices.com" rel="preconnect dns-prefetch"/><link crossorigin="" href="https://bid.g.doubleclick.net" rel="preconnect dns-prefetch"/><link crossorigin="" href="https://pagead2.googlesyndication.com" rel="dns-prefetch"/><link crossorigin="" href="https://googleads.g.doubleclick.net" rel="dns-prefetch"/><link crossorigin="" href="https://tpc.googlesyndication.com" rel="dns-prefetch"/><link crossorigin="" href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/><link crossorigin="" href="https://adservice.google.co.in" rel="dns-prefetch"/><link crossorigin="" href="https://stats.g.doubleclick.net" rel="dns-prefetch"/><link crossorigin="" href="https://www.google-analytics.com" rel="dns-prefetch"/><link crossorigin="" href="https://www.googleadservices.com" rel="dns-prefetch"/><link crossorigin="" href="https://connect.facebook.net" rel="dns-prefetch"/><link crossorigin="" href="https://s3.amazonaws.com" rel="dns-prefetch"/><link crossorigin="" href="https://ap-sonar.sociomantic.com" rel="dns-prefetch"/><link crossorigin="" href="https://api.survicate.com" rel="dns-prefetch"/><link crossorigin="" href="https://survey.survicate.com" rel="dns-prefetch"/><link crossorigin="" href="https://sb.scorecardresearch.com" rel="dns-prefetch"/><link crossorigin="" href="https://www.google.com" rel="dns-prefetch"/><link crossorigin="" href="https://www.google.co.in" rel="dns-prefetch"/><link crossorigin="" href="https://ampcid.google.com" rel="dns-prefetch"/><link crossorigin="" href="https://ampcid.google.co.in" rel="dns-prefetch"/><link crossorigin="" href="https://surveys-static.survicate.com" rel="dns-prefetch"/>
# <link as="font" crossorigin="" href="https://stc.aeplcdn.com/fonts/lato-bold.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin
 30 lakh? Here is the complete list. Check out price, images, specifications &amp; reviews of cars under 30 lakh." data-react-helmet="true" property="og:description"/><meta content="https://www.carwale.com/new/best-cars-under-30-lakh/" data-react-helmet="true" property="og:url"/><meta content="CarWale" data-react-helmet="true" property="og:site_name"/><meta content="https://imgd.aeplcdn.com/0x0/cw/design15/carwale.png?v=1.1" data-react-helmet="true" property="og:image"/><meta content="154881297559" data-react-helmet="true" property="fb:admins"/><meta content="154881297559" data-react-helmet="true" property="fb:page"/><meta content="481333722014878" data-react-helmet="true" property="fb:app_id"/><meta content="@CarWale" data-react-helmet="true" name="twitter:site"/><meta content="Best Cars Under 30 Lakh in India| Top Cars Below 30 Lakh" data-react-helmet="true" name="twitter:title"/><meta content="Looking to buy a car under 30 lakh? Here is the complete list. Check out price, images, specifications &amp; reviews of cars under 30 lakh." data-react-helmet="true" name="twitter:description"/><meta content="@CarWale" data-react-helmet="true" name="twitter:creator"/><meta content="https://imgd.aeplcdn.com/0x0/cw/design15/carwale.png?v=1.1" data-react-helmet="true" name="twitter:image"/>
# <script data-react-helmet="true" type="application/ld+json">{"@context":"https://schema.org/","@graph":[{"@type":"ItemList","itemListElement":[{"@type":"ListItem","position":1,"image":"https://imgd.aeplcdn.com/600x337/n/cw/ec/47051/compass-exterior-right-front-three-quarter-83.jpeg?isig=0&q=80","url":"https://www.carwale.com/jeep-cars/compass/","name":"Jeep Compass"},{"@type":"ListItem","position":2,"image":"https://imgd.aeplcdn.com/600x337/n/cw/ec/106815/creta-exterior-right-front-three-quarter-6.png?isig=0&q=80","url":"https://www.carwale.com/hyundai-cars/creta/","name":"Hyundai Creta"},{"@type":"ListItem","position":3,"image":"https://imgd.aeplcdn.com/600x337/n/cw/ec/194921/victoris-exterior-right-front-three-quarter-8.png?isig=0&q=80","url":"https://www.carwale.com/maruti-suzuki-cars/victoris/","name":"Maruti Suzuki Victoris"},{"@type":"ListItem","position":4,"image":"https://imgd.aeplcdn.com/600x337/n/cw/ec/40432/scorpio-n-exterior-right-front-three-quarter-75.jpeg?isig=0&q=80","url":"https://www.carwale.com/mahindra-cars/scorpio-n/","name":"Mahindra Scorpio N"},{"@type":"ListItem","position":5,"image":"https://imgd.aeplcdn.com/600x337/n/cw/ec/42355/xuv700-exterior-right-front-three-quarter-3.jpeg?isig=0&q=80","url":"https://www.carwale.com/mahindra-cars/xuv700/","name":"Mahindra XUV700"},{"@type":"ListItem","position":6,"image":"https://imgd.aeplcdn.com/600x337/n/cw/ec/124027/hyryder-exterior-right-front-three-quarter-74.png?isig=0&q=80","url":"https://www.carwale.com/toyota-cars/hyryder/","name":"Toyota Urban Cruiser Hyryder"},{"@type":"ListItem","position":7,"image":"https://imgd.aeplcdn.com/600x337/n/cw/ec/1/versions/mahindra-thar-roxx-mx1-petrol-mt-2wd1724144390186.jpg?q=80","url":"https://www.carwale.com/mahindra-cars/thar-roxx/","name":"Mahindra Thar Roxx"},{"@type":"ListItem","position":8,"image":"https://imgd.aeplcdn.com/600x337/n/cw/ec/131825/be-6e-exterior-right-front-three-quarter-5.jpeg?isig=0&q=80","url":"https://www.carwale.com/mahindra-cars/be-6/","name":"Mahindra BE 6"},{"@type":"ListItem","position":9,"image":"https://imgd.aeplcdn.com/600x337/n/cw/ec/174323/seltos-exterior-right-front-three-quarter.jpeg?isig=0&q=80","url":"https://www.carwale.com/kia-cars/seltos/","name":"Kia Seltos"},{"@type":"ListItem","position":10,"image":"https://imgd.aeplcdn.com/600x337/n/cw/ec/139245/harrier-facelift-right-front-three-quarter-4.jpeg?isig=0&q=80","url":"https://www.carwale.com/tata-cars/harrier/","name":"Tata Harrier"},{"@type":"ListItem","position":11,"image":"https://imgd.aeplcdn.com/600x337/n/cw/ec/115025/innova-hycross-exterior-right-front-three-quarter-73.jpeg?isig=0&q=80","url":"https://www.carwale.com/toyota-cars/innova-hycross/","name":"Toyota Innova Hycross"},{"@type":"ListItem","position":12,"image":"https://imgd.aeplcdn.com/600x337/n/cw/ec/140809/innova-crysta-exterior-right-front-three-quarter-2.png?isig=0&q=80","url":"https://www.carwale.com/toyota-cars/innova-crysta/","name":"Toyota Innova Crysta"},{"@type":"ListItem","position":13,"image":"https://imgd.aeplcdn.com/600x337/n/cw/ec/128413/scorpio-exterior-right-front-three-quarter-47.jpeg?isig=0&q=80","url":"https://www.carwale.com/mahindra-cars/scorpio/","name":"Mahindra Scorpio"},{"@type":"ListItem","position":14,"image":"https://imgd.aeplcdn.com/600x337/n/cw/ec/130595/xev-9e-exterior-right-front-three-quarter.jpeg?isig=0&q=80","url":"https://www.carwale.com/mahindra-cars/xev-9e/","name":"Mahindra XEV 9e"},{"@type":"ListItem","position":15,"image":"https://imgd.aeplcdn.com/600x337/n/cw/ec/138899/safari-facelift-right-front-three-quarter-2.jpeg?isig=0&q=80","url":"https://www.carwale.com/tata-cars/safari/","name":"Tata Safari"},{"@type":"ListItem","position":16,"image":"https://imgd.aeplcdn.com/600x337/n/cw/ec/1/versions/tata-harrier-ev-adventure1748956384144.jpg?q=80","url":"https://www.carwale.com/tata-cars/harrier-ev/","name":"Tata Harrier EV"}]},{"@type":"FAQPage","mainEntity":[{"@type":"Question","answerCount":1,"dateCreated":"2020-12-17","author ...
# <script>
# 	! function (n, e) {
# 		var t, o, i, c = [],
# 			f = {
# 				passive: !0,
# 				capture: !0
# 			},
# 			r = new Date,
# 			a = "pointerup",
# 			u = "pointercancel";
#
# 		function p(n, c) {
# 			t || (t = c, o = n, i = new Date, w(e), s())
# 		}
#
# 		function s() {
# 			o >= 0 && o < i - r && (c.forEach(function (n) {
# 				n(o, t)
# 			}), c = [])
# 		}
#
# 		function l(t) {
# 			if (t.cancelable) {
# 				var o = (t.timeStamp > 1e12 || !performance ? new Date : performance.now()) - t.timeStamp;
# 				"pointerdown" == t.type ? function (t, o) {
# 					function i() {
# 						p(t, o), r()
# 					}
#
# 					function c() {
# 						r()
# 					}
#
# 					function r() {
# 						e(a, i, f), e(u, c, f)
# 					}
# 					n(a, i, f), n(u, c, f)
# 				}(o, t) : p(o, t)
# 			}
# 		}
#
# 		function w(n) {
# 			["click", "mousedown", "keydown", "touchstart", "pointerdown"].forEach(function (e) {
# 				n(e, l, f)
# 			})
# 		}
# 		w(n), self.perfMetrics = self.perfMetrics || {}, self.perfMetrics.onFirstInputDelay = function (n) {
# 			c.push(n), s()
# 		}
# 	}(addEventListener, removeEventListener);
# </script> <style>
# @font-face {
# 	font-family: 'LatoGoogle';
# 	font-display: swap;
# 	src: url('https://stc.aeplcdn.com/fonts/lato-bold.woff2') format('woff2'),
# 		 url('https://stc.aeplcdn.com/fonts/lato-bold.woff') format('woff');
# 	font-weight: 700;
# 	font-style: normal;
# }
#
# @font-face {
# 	font-family: 'LatoGoogle';
# 	font-display: swap;
# 	src: url('https://stc.aeplcdn.com/fonts/lato-regular.woff2') format('woff2'),
# 		 url('https://stc.aeplcdn.com/fonts/lato-regular.woff') format('woff');
# 	font-weight: 400;
# 	font-style: normal;
# }
#
# 	</style>
# <style>
# a:active,a:hover,button{outline:0}a,button{background-color:transparent}img,legend{border:0}@-webkit-keyframes placeholderShimmer{0%{background-position:-512px 0}100%{background-position:512px 0}}@keyframes placeholderShimmer{0%{background-position:-512px 0}100%{background-position:512px 0}}/*! reset.css */*,:after,:before{margin:0;padding:0;-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box}/*! normalize.css v3.0.3 | MIT License | github.com/necolas/normalize.css */html{font-family:sans-serif;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%;-webkit-tap-highlight-color:transparent}article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section,summary{display:block}audio,canvas,progress,video{display:inline-block;vertical-align:baseline}audio:not([controls]){display:none;height:0}[hidden],template{display:none}a{text-decoration:none}abbr[title]{border-bottom:1px dotted}b,optgroup,strong{font-weight:700}small{font-size:80%}svg:not(:root){overflow:hidden}figure{margin:0}hr{box-sizing:content-box;height:0}pre,textarea{overflow:auto}button,input,optgroup,select,textarea{color:inherit;font:inherit;margin:0}button{overflow:visible;border:none}button,select{text-transform:none}button,html input[type=button],input[type=reset],input[type=submit]{-webkit-appearance:button;cursor:pointer}button[disabled],html input[disabled]{cursor:default}button::-moz-focus-inner,input::-moz-focus-inner{border:0;padding:0}input{line-height:normal}input[type=checkbox],input[type=radio]{box-sizing:border-box;padding:0}input[type=number]::-webkit-inner-spin-button,input[type=number]::-webkit-outer-spin-button{height:auto}input[type=search]{-webkit-appearance:textfield;box-sizing:content-box}input[type=search]::-webkit-search-cancel-button,input[type=search]::-webkit-search-decoration{-webkit-appearance:none}fieldset{border:1px solid silver;margin:0 2px;padding:.35em .625em .75em}legend{padding:0}table{border-collapse:collapse;border-spacing:0}td,th{padding:0}ol,ul{list-style:none}:root{--bg-color:#ffffff;--text-color:#484848}body.o-fzEmVn{--bg-color:#1a1a1a;--text-color:#d1d1d1}body{margin:0;font-size:14px;font-family:LatoGoogle,Lato,LatoWeb,sans-serif;color:var(--text-color)!important;background:var(--bg-color)}.show{display:block}.hide{display:none}.popup-container{position:relative;display:none}.commonActiveClasses:active,.commonActiveClasses:focus{opacity:.8}
# </style>
# <style data-css-theme="">.o-a{display:none}.o-b{display:inline}.o-c{display:block}.o-d{display:inline-block}.o-e{display:table}.o-f{display:-webkit-flex;display:flex}.o-g{display:-webkit-inline-flex;display:inline-flex}@media screen and (min-width:800px){.o-h{display:-webkit-flex;display:flex}}.o-i{vertical-align:baseline}.o-j{vertical-align:middle}.o-k{vertical-align:top}.o-l{vertical-align:bottom}.o-m{overflow:auto}.o-n{overflow:scroll}.o-o{overflow:hidden}.o-p{overflow:visible}.o-q{overflow:clip}.o-r{overflow-x:auto}.o-s{overflow-x:scroll}.o-t{overflow-x:hidden}.o-u{overflow-x:visible}.o-v{overflow-x:clip}.o-w{overflow-y:auto}.o-x{overflow-y:scroll}.o-y{overflow-y:hidden}.o-z{overflow-y:visible}.o-A{overflow-y:clip}.o-B{position:static}.o-C{position:relative}.o-D{position:absolute}.o-E{position:fixed}.o-F{position:-webkit-sticky;position:sticky}.o-G{top:0px}.o-H{top:2px}.o-I{top:4px}.o-J{top:8px}.o-K{top:12px}.o-L{top:16px}.o-M{top:40px}.o-N{top:auto}.o-O{top:50%}.o-P{top:100%}.o-Q{right:0px}.o-R{right:2px}.o-S{right:4px}.o-T{right:8px}.o-U{right:12px}.o-V{right:16px}.o-W{right:40px}.o-X{right:auto}.o-Y{right:50%}.o-Z{right:100%}.o-a0{bottom:0px}.o-a1{bottom:2px}.o-a2{bottom:4px}.o-a3{bottom:8px}.o-a4{bottom:12px}.o-a5{bottom:16px}.o-a6{bottom:40px}.o-a7{bottom:auto}.o-a8{bottom:50%}.o-a9{bottom:100%}.o-aa{left:0px}.o-ab{left:2px}.o-ac{left:4px}.o-ad{left:8px}.o-ae{left:12px}.o-af{left:16px}.o-ag{left:40px}.o-ah{left:auto}.o-ai{left:50%}.o-aj{left:100%}.o-ak{visibility:visible}.o-al{visibility:hidden}.o-am{z-index:0}.o-an{z-index:1}.o-ao{z-index:2}.o-ap{z-index:3}.o-aq{z-index:4}.o-ar{z-index:5}.o-as{z-index:6}.o-at{z-index:8}.o-au{z-index:10}.o-av{-webkit-flex-direction:row;flex-direction:row}.o-aw{-webkit-flex-direction:column;flex-direction:column}.o-ax{-webkit-flex-direction:row-reverse;flex-direction:row-reverse}.o-ay{-webkit-flex-direction:column-reverse;flex-direction:column-reverse}.o-az{-webkit-flex-wrap:wrap;flex-wrap:wrap}.o-aA{-webkit-flex-wrap:nowrap;flex-wrap:nowrap}.o-aB{-webkit-flex-wrap:wrap-reverse;flex-wrap:wrap-reverse}.o-aC{-webkit-align-items:flex-start;align-items:flex-start}.o-aD{-webkit-align-items:flex-end;align-items:flex-end}.o-aE{-webkit-align-items:center;align-items:center}.o-aF{-webkit-align-items:baseline;align-items:baseline}.o-aG{-webkit-align-items:stretch;align-items:stretch}.o-aH{-webkit-align-self:flex-end;align-self:flex-end}.o-aI{-webkit-align-self:center;align-self:center}.o-aJ{-webkit-justify-content:flex-start;justify-content:flex-start}.o-aK{-webkit-justify-content:flex-end;justify-content:flex-end}.o-aL{-webkit-justify-content:center;justify-content:center}.o-aM{-webkit-justify-content:space-between;justify-content:space-between}.o-aN{-webkit-justify-content:space-around;justify-content:space-around}.o-aO{-webkit-justify-content:space-evenly;justify-content:space-evenly}.o-aP{-webkit-align-content:center;align-content:center}.o-aQ{-webkit-flex-grow:0;flex-grow:0}.o-aR{-webkit-flex-grow:1;flex-grow:1}.o-aS{-webkit-flex-shrink:0;flex-shrink:0}.o-aT{-webkit-flex-shrink:1;flex-shrink:1}.o-aU{-webkit-flex-basis:0%;flex-basis:0%}.o-aV{-webkit-flex-basis:auto;flex-basis:auto}.o-aW{-webkit-flex-basis:8.3333%;flex-basis:8.3333%}.o-aX{-webkit-flex-basis:16.6667%;flex-basis:16.6667%}.o-aY{-webkit-flex-basis:25%;flex-basis:25%}.o-aZ{-webkit-flex-basis:33.3333%;flex-basis:33.3333%}.o-b0{-webkit-flex-basis:41.6667%;flex-basis:41.6667%}.o-b1{-webkit-flex-basis:50%;flex-basis:50%}.o-b2{-webkit-flex-basis:58.3333%;flex-basis:58.3333%}.o-b3{-webkit-flex-basis:66.6667%;flex-basis:66.6667%}.o-b4{-webkit-flex-basis:75%;flex-basis:75%}.o-b5{-webkit-flex-basis:83.3333%;flex-basis:83.3333%}.o-b6{-webkit-flex-basis:91.6667%;flex-basis:91.6667%}.o-b7{-webkit-flex-basis:100%;flex-basis:100%}@media screen and (min-width:800px){.o-b8{-webkit-flex-direction:row;flex-direction:row}.o-b9{-webkit-flex-direction:column;flex-direction:column}.o-ba{-webkit-align-items:flex-start;align-items:flex-start}.o-bb{-webki ...
# <style id="__CSS_MODULES__">.uKc5ca{height:56px}.zUY2LC{max-width:1366px}.uwdbAZ{box-shadow:0 2px 5px 0 rgba(0,0,0,.1);height:56px}@media screen and (min-width:960px){.H4FGov{min-width:224px}}.sT0Gjo{height:56px;width:64px}@media screen and (min-width:960px){.sT0Gjo{display:block}}@media screen and (min-width:960px){.nS6XVS:not(:first-child){margin-left:60px}}.dvEJRN{border-bottom-width:4px}.qDQpiv{-webkit-flex-basis:320px;flex-basis:320px}.UjkQAS{-webkit-flex-basis:396px;flex-basis:396px}.XvuFZU input:focus{box-shadow:0 2px 4px 2px hsla(0,0%,84%,.5)}.XeGa1P{top:-20px}.vOlJei{padding-left:110px}.CXPRav{padding-left:135px}._5sksb{font-size:12px}._5sksb+fieldset{top:-8px}.Cxdcp3{height:52px}.ESQzus{-webkit-transform:translateX(93px);transform:translateX(93px)}.Xz3P74{-webkit-transform:translate(120px,5px);transform:translate(120px,5px)}.W0qW_Z{left:130px;right:50px}.jCabaD+div{right:0}.gRAZ9y:focus{border-color:#3fbfff}.ayFmbh:disabled::-webkit-input-placeholder{color:#6f6f6f}._Y8Oy6:focus+fieldset{border-color:#333}.b36DQo:focus+fieldset{border-color:#0979b6}.VHPviE::-webkit-input-placeholder{color:#6f6f6f;font-weight:400}.VHPviE:focus{outline:0}.i6iQ_X{padding-right:50px}._c6ZVA{padding-left:50px}.i5Nek3{color:#6f6f6f}.i5Nek3::-webkit-calendar-picker-indicator{background-image:url(https://imgd.aeplcdn.com/0x0/cw/static/icons/svg/tools/calendar.svg)}.JSxWHP{color:#333}.JSxWHP::-webkit-calendar-picker-indicator{background-image:url(https://imgd.aeplcdn.com/0x0/cw/static/icons/svg/tools/calendar-charcoal.svg)}@media (max-width:480px){.i5Nek3,.JSxWHP{-webkit-appearance:none;-moz-appearance:none;appearance:none;background:transparent}.i5Nek3::-webkit-date-and-time-value,.JSxWHP::-webkit-date-and-time-value{display:inline-block;text-align:left}}.g4Lg6E:first-child{margin-top:0}.mkUuup:last-child{border-bottom-width:0}.nEqnYW:hover{background-color:#efefef}.Dr0hmb{max-width:304px}@media screen and (min-width:800px){.Dr0hmb{max-width:340px}}.PFhfey>a{color:#0979b6}@media screen and (min-width:800px){.PFhfey{border-radius:4px}}.mj86in{box-shadow:0 0 4px 0 rgba(0,0,0,.15)}.f192x7:after{background-color:#333;border-bottom:1px solid #efefef;border-right:1px solid #efefef;bottom:100%;content:"";height:8px;left:8px;pointer-events:none;position:absolute;top:-5px;width:8px}.rTKxlt,.f192x7:after{-webkit-transform:rotate(-135deg);transform:rotate(-135deg)}.cSWIgx{top:-4px}.FuBd_a{bottom:-4px}@media screen and (min-width:800px){.Q11zJB{max-width:800px}}@media screen and (min-width:960px){.Q11zJB{max-width:960px}}@media screen and (min-width:1008px){.Q11zJB{max-width:1008px}}.yUldIv a{color:#0979b6}.tqWhrt{transition:-webkit-transform .5s;transition:transform .5s;transition:transform .5s,-webkit-transform .5s}.oHQoVh,.cAgKJj,.j2u3f2{border-bottom-right-radius:8px;border-top-right-radius:8px}.cAgKJj{background:linear-gradient(90deg,transparent,#f9f9f9 24px,#f9f9f9)}.j2u3f2{background:linear-gradient(90deg,hsla(0,0%,100%,0) 0,hsla(0,0%,100%,.929) 25%,#fff)}.oHQoVh{background:linear-gradient(270deg,#333 60%,#333 0,transparent)}.PGv5gc{background:linear-gradient(transparent,#fff 50%,#fff)}.evjKut{background:linear-gradient(transparent,#f9f9f9 50%,#f9f9f9)}.BbbiQF{bottom:-8px}.aXlX4B{display:-webkit-box;-webkit-box-orient:vertical}.T_zHfo{max-height:220px}.YmehmS a,.yFf7uL a{color:#0979b6}.GMWGSu{display:table-row}.KPWm6w:hover{background-color:#efefef}.L1MKH3{display:table-header-group}.QeYx22{display:table-row-group}.QeYx22 td,.QeYx22 th{font-weight:400}.I4PRaX{display:table-footer-group}.T3wLJ0 tr{background-color:inherit}.T3wLJ0 td,.T3wLJ0 th{background-color:inherit;left:0;position:-webkit-sticky;position:sticky;top:0;z-index:1}.y7x7xR{border-collapse:collapse}.SAT53z tr{border-bottom-color:inherit;border-bottom-style:solid;border-bottom-width:1px}.fFe1La td,.fFe1La th{border-left-color:inherit;border-left-style:solid;border-left-width:1px}.hfViES td:first-child,.hfViES th:first-child,.DhU5ab tbody tr:last-child{border:none}.J6onGA tbody tr:last- ...
# <script>
# 		(function (w, d, s, l, i) {
# 			w[l] = w[l] || []; w[l].push({
# 				'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 			}); var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.defer = true; j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 			f.parentNode.insertBefore(j, f);
# 		})(window, document, 'script', 'dataLayer', 'GTM-W2Z3ZM');
# 	</script>
# <script type="text/javascript">
#   function isAbTestUrl() {
# 	const LOADING_SCRIPTS_ON_SCROLL_PATHNAME_REGEX = [
# 	  new RegExp("\/used\/$"),
# 	  new RegExp("\/used\/absure\/$"),
# 	  new RegExp("\/used\/([a-zA-Z0-9_-]+)\/absure\/$"),
# 	  new RegExp("\/used\/([a-zA-Z0-9_-]+)\/$"),
# 	  new RegExp("\/used\/([a-zA-Z0-9_-]+)\/([a-zA-Z0-9_-]+)\/([a-zA-Z0-9_-]+)\/$")];
# 	for (var count = 0; count < LOADING_SCRIPTS_ON_SCROLL_PATHNAME_REGEX.length; count++) {
# 	  if (LOADING_SCRIPTS_ON_SCROLL_PATHNAME_REGEX[count].test(window.location.pathname)) return true;
# 	}
# 	return false;
#   }
#   var isValidAbTestPathName = isAbTestUrl();
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#
#   var gptRan = false;
#
#   // commented to pause pubmatic ads
#   var loadGpt = function () {
# 	// Check the gptRan flag
# 	if (!gptRan) {
# 	  gptRan = true;
# 	  var gads = document.createElement('script');
# 	  gads.defer = true;
# 	  var useSSL = 'https:' == document.location.protocol;
# 	  gads.src = (useSSL ? 'https:' : 'http:') + '//www.googletagservices.com/tag/js/gpt.js';
# 	  var node = document.getElementsByTagName('script')[0];
# 	  if (isValidAbTestPathName) {
# 		if (window._LOAD_SCRIPT_EVENT_) {
# 		  node.parentNode.insertBefore(gads, node);
# 		}
# 		else {
# 		  window.addEventListener("loadScriptsEvent", function () { node.parentNode.insertBefore(gads, node); }, false)
# 		}
# 	  }
# 	  else {
# 		window.addEventListener("load", function () { setTimeout(function () { node.parentNode.insertBefore(gads, node); }, 5000); }, false)
# 	  }
# 	}
#   }
#   loadGpt();
# </script> <meta content="y33JBqCALrAtfZBeI-VVHz7jyLJrZqpOsggckAZlBj8" name="google-site-verification"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0" name="viewport"/>
# <meta content="strict-origin-when-cross-origin" name="referrer"/>
# <link href="https://imgd.aeplcdn.com/0x0/cw/design15/cw-logo.ico?v1" rel="SHORTCUT ICON"/>
# <script key="gtagDef" name="gtagDef">
# 		var googletag = googletag || {};
# 		googletag.cmd = googletag.cmd || [];
# 		googletag.cmd.push(function () {
# 			googletag.pubads().enableSingleRequest();
# 			googletag.pubads().disableInitialLoad();
# 			googletag.pubads().enableLazyLoad({
# 				fetchMarginPercent: 0,  // Fetch slots within 2 viewports.
# 				renderMarginPercent: 100,  // Render slots within 2 viewports.
# 				mobileScaling: 1.0  // same scaling on mobile and desktop.
# 			});
# 			googletag.pubads().collapseEmptyDivs();
# 			googletag.enableServices();
#
# 			googletag.pubads().addEventListener('slotRenderEnded', function (event) {
# 				var slotId = event.slot.getSlotElementId();
# 				var slotElement = document.getElementById(slotId);
# 				 var size = event.size;
# 				if (slotElement) {
# 					var slotParentElement = slotElement.parentElement;
# 					if (!slotParentElement) {
# 						return;
# 					}
# 					var isAdParent = slotParentElement.classList.contains('js-ad-slot-parent');
# 					var showOnlyDirectAd = slotParentElement.classList.contains('js-direct-ad-slot');
# 					var isResizeable = slotParentElement.classList.contains('js-resizeable-ad-slot');
# 					var grayOutSectionOnFailedAdLoad = slotParentElement.classList.contains('js-grayout-ad-slot-on-fail');
# 					var isFixedHeightForNewAdVariant = slotParentElement.classList.contains('js-resize-fail-add-variant-A');
# 					var shouldRemoveMargin = slotParentElement.classList.contains('js-remove-margin-on-placeholder');
# 					const adLoaderElement = slotParentElement.querySelector('.js-show-loader');
# 					const adTextElement = slotParentElement.querySelector('.js-ad-text');
# 					if (!isAdParent) {
# 						return;
# 					}
# 					if (size!=null && slotParentElement.clientHeight>0 && size[1] > slotParentElement.clientHeight) {
# 						console.log("slot rendered"+slotParentElement.clientHeight+" "+size[1]);
# 					   slotParentElement.style.height = size[1] + 'px';
# 					}
#
# 					if (isAdParent && !isResizeable && event.isEmpty && !isFixedHeightForNewAdVariant && !showOnlyDirectAd) {
# 						// Need to handle resizable case
# 						slotParentElement.style.display = "none";
# 						return;
# 					}
#
# 					if(adLoaderElement && adTextElement) {
# 						adLoaderElement.remove();
# 						adTextElement.remove();
# 						slotParentElement.style.backgroundColor = "transparent";
# 					}
# 					// Update resizeable ad-slot container height
# 					if (event.isEmpty) {
# 						if (grayOutSectionOnFailedAdLoad) {
# 							slotParentElement.style.backgroundColor = '#efefef';
# 							slotParentElement.style.marginLeft = "16px";
# 							slotParentElement.style.marginRight = "16px";
# 							slotParentElement.style.color = "#b5b5b5";
# 							slotElement.innerText = "AD";
# 							slotElement.style.alignItems = "center";
# 							slotElement.style.height = "100%";
# 							slotElement.style.display = "flex";
# 							slotElement.style.justifyContent = "center";
# 							if(shouldRemoveMargin) {
# 								slotParentElement.style.marginLeft = "0px";
# 								slotParentElement.style.marginRight = "0px";
# 							}
# 						}
# 						else {
# 							slotParentElement.style.height = 0;
# 							slotParentElement.style.margin = 0;
# 						}
# 					} else if (!isFixedHeightForNewAdVariant) {
# 						var adSlotHeight = event.size && event.size[1]; // ad slot size: [320, 50]
# 						slotParentElement.style.height = adSlotHeight + 'px';
# 					}
# 				}
# 			});
# 		});
# 	</script></head><body class="pwa-root" data-skin="Not Set"><div id="portal-root"></div>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-W2Z3ZM" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <input name="__RequestVerificationToken" type="hidden" value="CfDJ8JUh_GoNOjhBqUJ2d7OuCzTj8GJdat-PreGTFWY0R-0-faEKmlMHl0ekwPfGY9iMXrCJnVpquy4WTJCyUncHGy8-xeiSe5mBlehRyZqolSIOJ7UHqhbOXgVO4G4LywJ_53_OHPofPPkmdmJZkQTnqHQ"/>
# <div class="speedometer__container hide" id="speedometer_loader_view"><div class="speedometer-loader__content"><div class="speedometer-loader"></div><div class="speedometer-needle-circle"></div></div></div>
# <div id="root"><div class="uKc5ca o-hl"><header class="o-as o-kY o-hl uwdbAZ o-E o-G o-a0 o-aa o-Q"><div class="zUY2LC o-aM o-iD o-aE o-cG o-ca o-eL o-fj o-f"><div class="o-aE H4FGov o-f"><div class="o-iD"><a class="o-c o-j1" href="/" title="CarWale"><img alt="CarWale" src="https://imgd.aeplcdn.com/0x0/cw/static/icons/new-header/logo.svg" title="CarWale" width="136"/></a></div></div><nav class="o-fd o-eF o-f o-aM o-aV o-aS o-aR"><ul class="o-j3 o-f"><li class="nS6XVS"><div class="o-os o-js o-jy o-kF o-mo o-ef o-bS o-co o-mJ dvEJRN">NEW CARS</div></li><li class="o-fh nS6XVS"><div class="o-os o-js o-jy o-kF o-mo o-ef o-bS o-co o-mJ dvEJRN">USED CARS</div></li><li class="o-fh nS6XVS"><div class="o-os o-js o-jy o-kF o-mo o-ef o-bS o-co o-mJ dvEJRN">REVIEWS &amp; NEWS</div></li></ul></nav><div class="o-aE o-jK o-aR o-aT o-aV o-aK o-f"><div class="o-eF o-aQ o-aT o-os o-iW qDQpiv" title="Search"><div class="o-ar o-C" data-section-id="global-search"><div aiassistant="" class="o-C o-ov" inputsize="md" maxselectedwidth="100%" tabindex="-1" trendingsearcheslabel="Trending Searches"><div class="o-d o-C o-hl o-ao"><div class="o-C"><input aria-label="Input field" class="o-iU o-d o-p o-hl o-jJ o-kY o-j4 o-bQ o-cm o-mL o-nc o-lT o-mf o-cE VHPviE gRAZ9y i6iQ_X VHPviE jCabaD o-nc" customlabelclassname="Xz3P74" max="" maxselectedwidth="100%" min="" placeholder="Search" prefixpositionclassname="o-ac" type="text" value=""/><div class="o-D o-ox o-jJ o-j4 o-O o-om o-V"><svg aria-hidden="true" class="o-aQ o-aS o-aV o-ov o-gV o-ie o-eD o-f o-jK" fill="currentcolor" focusable="false" role="img" tabindex="-1" viewbox="0 0 16 16"></svg></div></div></div><div class="o-w o-lT o-mN o-oA o-ekdNkn o-a o-P o-ny o-nv o-ml o-mr o-mo o-D o-aa o-Q o-kY o-an" style="max-height:300px"><div activeposition="-1" class="o-jA o-jJ o-j1"><ul></ul></div></div></div></div></div><div class="o-C o-os o-eB o-C" title="Location"><div class="o-d"><svg aria-hidden="true" class="o-aQ o-aS o-aV o-ov o-gW o-if" fill="currentcolor" focusable="false" role="img" tabindex="-1" viewbox="0 0 16 16"><path d="M8.11 15.89c-.28 0-.55-.12-.74-.32-.97-1.05-3.95-4.85-4.79-8.45-.49-2.61.31-4.8 2.2-6.04 1.97-1.29 4.81-1.28 6.75.03 1.84 1.25 2.61 3.43 2.09 6-.74 3.43-3.77 7.35-4.78 8.45a1 1 0 01-.74.33zm.04-14.78c-1 0-1.99.27-2.81.81-1.55 1.02-2.18 2.8-1.77 5 .79 3.36 3.62 6.97 4.54 7.97.96-1.05 3.85-4.78 4.55-7.98.44-2.18-.16-3.95-1.67-4.97-.82-.55-1.82-.83-2.83-.83zm-.04 7.38c-1.56 0-2.84-1.25-2.84-2.78s1.27-2.78 2.84-2.78 2.84 1.25 2.84 2.78-1.27 2.78-2.84 2.78zm0-4.55c-1.01 0-1.84.8-1.84 1.78S7.09 7.5 8.11 7.5s1.84-.8 1.84-1.78-.82-1.78-1.84-1.78z"></path></svg></div></div><div class="o-fb o-os o-C"><svg aria-hidden="true" class="o-aQ o-aS o-aV o-ov o-gW o-if o-jK" fill="currentcolor" focusable="false" role="img" tabindex="-1" viewbox="0 0 16 16"></svg></div></div></div></header></div><div class="o-gr o-fT o-hA Q11zJB o-df o-dL"><section class="o-bQ o-cm o-C" data-section-id="filter-page-section" data-skin="section"><div class="o-f9 o-gb o-eB o-fD o-ee"><h1 class="o-j6 o-jm o-eO o-fY" data-lang-id="filter_page_heading" data-skin="text">Best Cars Under 30 Lakh</h1><div class="o-C o-o o-j2" data-skin="seo-text"><div class="o-hl o-iT o-o" style="transition:max-height linear 500ms;max-height:43px;-webkit-line-clamp:unset"><div><p class="o-eU o-g3 o-jz o-jK o-j1 o-jh yUldIv" data-lang-id="filter_description_seo_text" data-skin="text">Are you planning on buying a car under Rs. 30 lakh? Well,
#                     we know that budget is one of the most crucial things while buying a car and with so many options available out there,
#                     it gets really difficult to find a good car which suits your pocket. Hence, we have put together a complete list of best cars under Rs. 30 lakh.
\u0022,\u0022name\u0022:\u0022Mahindra BE 6\u0022},{\u0022@type\u0022:\u0022ListItem\u0022,\u0022position\u0022:9,\u0022image\u0022:\u0022https://imgd.aeplcdn.com/600x337/n/cw/ec/174323/seltos-exterior-right-front-three-quarter.jpeg?isig=0\u0026q=80\u0022,\u0022url\u0022:\u0022https://www.carwale.com/kia-cars/seltos/\u0022,\u0022name\u0022:\u0022Kia Seltos\u0022},{\u0022@type\u0022:\u0022ListItem\u0022,\u0022position\u0022:10,\u0022image\u0022:\u0022https://imgd.aeplcdn.com/600x337/n/cw/ec/139245/harrier-facelift-right-front-three-quarter-4.jpeg?isig=0\u0026q=80\u0022,\u0022url\u0022:\u0022https://www.carwale.com/tata-cars/harrier/\u0022,\u0022name\u0022:\u0022Tata Harrier\u0022},{\u0022@type\u0022:\u0022ListItem\u0022,\u0022position\u0022:11,\u0022image\u0022:\u0022https://imgd.aeplcdn.com/600x337/n ...
# 	window.__CLIENT_RENDER__ = false;
# 	window.__IS_MOBILE__ = false;
# </script>
# <link data-chunk="main-desktop" href="https://stc.aeplcdn.com/staticminv2/css/main-desktop.735b0ace0.css" rel="stylesheet"/><script id="__CSS_MODULES_IDS__" type="application/json">["tJ87sbm2VO","iVe+y4hBQB","VXz6eXKbEU","h1o4DcqGkf","QoXMm2d2hM","LyboC0xIS+","XHbKYwfCMq","tFCC7t-Qwh","z4l4KyElSZ","wrJPoY-yZn","JzKIjr0kYW","_6q7h4PM7ho","O2dCTHmkcQ","_5JqMU4t+Nm","xX2C2EawNT","AqIeYRWPOE","EFHSVIqzOr","sE1lLCt0zm","_2yYrUQ6RX-","dc6d-ABHkN","_8H4dIGhIbk","efA2f0T3OD","ZBSRNmXz94","pqMNjlQPYX","LJNyFMYoVF","_4gRSoWhULN","O-L-FiVBYw","_1pF2Kv6cUc","bv71+SCZPk","MKC9NF14A4","_0EzotPfVWP","kaac7p8fj4","CPHFLYFQHX","-KMdW6ksXL","gInFlS9vO3","brdGq2zgbf","bTF4yByIys","YB1chm7lSj","BcgxBFjzGK","gAbOVPeDXx","hw3nauwE6N","ZKBIB6BoEZ","vhFfKCviJ-","Mnp-aGn6wr","X-n-VBwSlo","NmvK9s6u5f","B6aO+wlVnC","_1jQTOdgp8U","_7sqB5eDMXf","tiVw2-qlnB"]</script>
# <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">["defaultvendors-8303fb3dc3c0a5b3626bd6402770ac7c","defaultvendors-11545d2535e2e3a73c27a21ef09b9a50","defaultvendors-93ad602f2b3fd4cde94eb32121ecb2e0","default-fcf8b7c756a84689ee5a8709c4a4827c","default-920d6a5307ee27f8f587369bc38f5061","default-b36e6ce78c1fcfbd89fc60940065ee3c","default-9f9482cf9414ff64f030a07d6f97bbb3","default-1365fc2583020d9279128dfb496b668c","default-616a80fed88a7bd3255c2d1935d7698d","best-cars-by-filter-desktop","defaultvendors-7803e91766d9a3fd598a9ee843ab159b","defaultvendors-6916802f741d16911db3dc7072a1d949","defaultvendors-8c1e8aa6a953b4d3b77fe51aae46f360","defaultvendors-285ea758a36207b8a458a2d93a9fcaf3","defaultvendors-31a1eafb609882912f17e3b787b6f346","defaultvendors-03434221c09daf310b126459cb141ea5","leadformcta"]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":
# <script data-chunk="leadformcta" data-src="https://stc.aeplcdn.com/staticminv2/js/leadformcta.deb4f75ac2.en.js" defer=""></script>
# <script>
# 			function loadScriptsCallback() {
# 				var scripts = document.getElementsByTagName("script");
# 				for (var i = 0; i < scripts.length; i++) {
# 					if (scripts[i].dataset.src != null) {
# 						scripts[i].src = scripts[i].dataset.src;
# 					}
# 				}
# 			}
#
# 			function loadScripts() {
# 				window.requestIdleCallback
# 					? window.requestIdleCallback(loadScriptsCallback)
# 					: loadScriptsCallback()
# 			}
# 			if (document.readyState === "complete"
# 				|| document.readyState === "loaded"
# 				|| document.readyState === "interactive") {
# 				loadScripts()
# 			}
# 			else {
# 				document.addEventListener("DOMContentLoaded", loadScripts);
# 			}
# 		</script>
# <script>
# 		var cityAutocompleteAbTest = 50;
# 		window.__PLATFORM_ID__ = 1;
# 		window.APP_VERSION = 0;
# 		window.NEXT_VERSION = window.APP_VERSION;
# 		window.originalLocationPath = window.originalLocationPath || (window.location.protocol + '//' + window.location.hostname + window.location.pathname + window.location.search);
# 	</script><script defer="" src="https://www.gstatic.com/firebasejs/8.4.3/firebase-app.js"></script><script defer="" src="https://www.gstatic.com/firebasejs/8.4.3/firebase-messaging.js"></script><script type="text/javascript">
# 		if (window.navigator && navigator.serviceWorker) {
# 			navigator.serviceWorker.getRegistrations().then(registrations => {
# 				for (const registration of registrations) {
# 					if (registration.active.scriptURL === `${window.location.origin}/~partytown/partytown-sw.js`) {
# 						registration.unregister();
# 					}
# 				}
# 			});
# 		}
# 	</script></body></html>

# %% [markdown]
# ### 🎨 Pretty Printing HTML
# ```python
# soup.prettify()
# ```
#
# ---
#
# ### 🤔 What Does `prettify()` Do?
#
# **Simple Explanation:**
#
# - 📐 **Formats HTML neatly** - Adds proper indentation and line breaks
# - 👀 **Makes it readable** - Transforms messy HTML into organized structure
# - 🔍 **Easy to understand** - Shows parent-child relationships clearly
# - 📝 **Debugging tool** - Helps you see the HTML structure at a glance
# - ✨ **Beautifies code** - Converts single-line HTML into multi-line formatted text
#
# ---
#
# ### 📊 Visual Comparison
#
# **Before `prettify()`:**
# ```html
# <html><head><title>Page</title></head><body><h1>Hello</h1><p>Text</p></body></html>
# ```
#
# **After `prettify()`:**
# ```html
# <html>
#  <head>
#   <title>
#    Page
#   </title>
#  </head>
#  <body>
#   <h1>
#    Hello
#   </h1>
#   <p>
#    Text
#   </p>
#  </body>
# </html>
# ```
#
# ---
#
# ### 💡 When to Use It?
#
# - ✅ When you want to **see the HTML structure**
# - ✅ For **debugging** your scraping code
# - ✅ To **understand page layout** before extracting data
#
# ---

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html itemscope="" itemtype="http://schema.org/WebPage" lang="en" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="#0e3a50" name="theme-color"/>\n  <meta content="max-snippet:-1, max-image-preview:large" name="robots"/>\n  <title data-react-helmet="true" itemprop="name">\n   Best Cars Under 30 Lakh in India| Top Cars Below 30 Lakh - CarWale\n  </title>\n  <link crossorigin="" href="https://imgd.aeplcdn.com" rel="preconnect dns-prefetch"/>\n  <link crossorigin="" href="https://stc.aeplcdn.com" rel="preconnect dns-prefetch"/>\n  <link crossorigin="" href="https://www.googletagmanager.com" rel="preconnect dns-prefetch"/>\n  <link crossorigin="" href="https://www.googletagservices.com" rel="preconnect dns-prefetch"/>\n  <link crossorigin="" href="https://bid.g.doubleclick.net" rel="preconnect dns-prefetch"/>\n  <link crossorigin="" href="https://pagead2.googlesyndication.com" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://googleads.g.doubleclick.net" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://tpc.googlesyndication.com" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://adservice.google.co.in" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://stats.g.doubleclick.net" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://www.google-analytics.com" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://www.googleadservices.com" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://connect.facebook.net" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://s3.amazonaws.com" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://ap-sonar.sociomantic.com" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://api.survicate.com" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://survey.survicate.com" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://sb.scorecardresearch.com" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://www.google.com" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://www.google.co.in" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://ampcid.google.com" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://ampcid.google.co.in" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://surveys-static.survicate.com" rel="dns-prefetch"/>\n  <link as="font" crossorigin="" href="https://stc.aeplcdn.com/fonts/lato-bold.woff2" rel="preload" type="font/woff2"/>\n  <link as="font" crossorigin="" href="https://stc.aeplcdn.com/fonts/lato-regular.woff2" rel="preload" type="font/woff2"/>\n  <link as="image" href="" rel="preload"/>\n  <link as="style" data-chunk="main-desktop" href="https://stc.aeplcdn.com/staticminv2/css/main-desktop.735b0ace0.css" rel="preload"/>\n  <link data-react-helmet="true" href="/manifest.webmanifest.json?v=1" rel="manifest"/>\n  <link data-react-helmet="true" href="https://www.carwale.com/new/best-cars-under-30-lakh/" rel="canonical"/>\n  <link data-react-helmet="true" href="https://www.carwale.com/new/best-cars-under-30-lakh/" rel="alternate"/>\n  <link data-react-helmet="true" href="https://www.carwale.com/new/best-cars-under-30-lakh/" hreflang="en" rel="alternate"/>\n  <link data-react-helmet="true" href="https://www.carwale.com/hi/new/best-cars-under-30-lakh/" hreflang="hi" rel="alternate"/>\n  <link data-react-helmet="true" href="https://www.carwale.com/new/best-cars-under-30-lakh/" hreflang="x-default" rel="alternate"/>\n  <link data-react-helmet="true" href="/new/best-cars-under-30-lakh/2/" rel="next"/>\n  <link as="image" data-react-helmet="true" href="https://imgd.aeplcdn.com/227x128/n/cw/ec/47051/compass-exterior-right-front-three-quarter-83.jpeg?isig=0&amp;q=80" rel="preload"/>\n  <link as="image" data-react-helmet="true" href="https://imgd.aeplcdn.com/227x128/n/cw/ec/106815/creta-exterior-right-front-three- ...

# %% [markdown]
# ### 🎯 Extracting Car Names from H3 Tags
# ```python
# soup.find_all('h3')
# soup.find_all('h3')[0]
# for i in soup.find_all('h3'):
#     print(i.text.strip())
# ```
#
# ---
#
# ### 🔍 How Did We Know to Use `h3`?
#
# **The Investigation Process:**
#
# 1. 🌐 **Visit the website** - Open the CarWale page
# 2. 🖱️ **Right-click on car name** - Select "Inspect" or "Inspect Element"
# 3. 📋 **Check the Elements tab** - Browser DevTools opens
# 4. 🔎 **Examine each car card** - Look at the HTML structure
# 5. ✅ **Found it!** - Car names are inside `<h3>` tags
#
# ---
#
# ### 🛠️ Code Breakdown
#
# | Code | What It Does | Output |
# |------|--------------|--------|
# | `soup.find_all('h3')` | Gets **all** `<h3>` tags from page | List of all h3 elements |
# | `soup.find_all('h3')[0]` | Gets **first** `<h3>` tag only | Single h3 element |
# | `for i in soup.find_all('h3'):` | **Loops through** each h3 tag | Iterates over all h3s |
# | `i.text.strip()` | Extracts **clean text** from tag | "Tata Nexon" |
#
# ---
#
# ### 📝 What This Extracts
#
# **Output Example:**
# ```
# Tata Nexon
# Hyundai Creta
# Maruti Suzuki Grand Vitara
# Kia Seltos
# Honda City
# ...
# ```
#
# Each line is a **car name** extracted from the `<h3>` tags! 🚗
#
# ---
#
# ### 💡 The Inspection Process
# ```
# Website → Inspect Element → Find Pattern → Use in Code
#    🌐   →       🔍        →      <h3>    →  find_all('h3')
# ```
#
# **Why `h3` specifically?**
# Because that's where the **car names** are stored in the HTML structure! 🎯
#
# ---
#
# ### ✅ Key Takeaway
#
# Always **inspect the website first** to find the correct HTML tags before scraping! 🔍✨
#
# ---

# %%
soup.find_all('h3')
soup.find_all('h3')[0]
for i in soup.find_all('h3'):
  print(i.text.strip())
# Out:
# Jeep Compass
# Hyundai Creta
# Maruti Suzuki Victoris
# Mahindra Scorpio N
# Mahindra XUV700
# Toyota Urban Cruiser Hyryder
# Mahindra Thar Roxx
# Mahindra BE 6
# Kia Seltos
# Tata Harrier
# Toyota Innova Hycross
# Toyota Innova Crysta
# Mahindra Scorpio
# Mahindra XEV 9e
# Tata Safari
# Tata Harrier EV
# Top SUVs in India
# Top Sedans in India
# Top Hatchbacks in India
# Top Compact SUVs in India
# Top Luxury Cars in India

# %% [markdown]
# ### 💰 Extracting Average Ex-Showroom Price
# ```python
# # Finding average ex-showroom price
#
# # soup.find_all('span').text  ❌ This gives ERROR!
# # Why? Because many elements use <span> tag, not just prices
#
# # Solution: Use the specific CLASS of the price span
#
# for i in soup.find_all('span', class_='o-j5 o-ji o-jJ o-js'):
#     print(i.text.strip())
# ```
#
# ---
#
# ### ❌ Why `soup.find_all('span')` Fails?
#
# **The Problem:**
#
# - 🏷️ **Too many span tags** - Hundreds of `<span>` elements on the page
# - 🎯 **Not specific enough** - Can't distinguish price spans from others
# - ⚠️ **Wrong data** - Gets random text, not just prices
#
# ---
#
# ### ✅ Solution: Use `class_` Attribute
# ```python
# soup.find_all('span', class_='o-j5 o-ji o-jJ o-js')
# ```
#
# **What this does:**
#
# - 🎯 **Targets specific spans** - Only spans with this exact class
# - 💰 **Gets only prices** - Filters out unwanted span tags
# - ✨ **Clean output** - Extracts just the ex-showroom prices
#
# ---
#
# ### 📝 Output Example
# ```
# ₹ 8.00 - 15.50 Lakh
# ₹ 11.00 - 20.30 Lakh
# ₹ 10.99 - 20.09 Lakh
# ₹ 10.90 - 20.35 Lakh
# ...
# ```
#
# ---
#
# ### 💡 Key Lesson
#
# **Generic tag** (`span`) = ❌ Too broad
# **Tag + Class** (`span` with specific class) = ✅ Precise targeting! 🎯
#
# ---

# %%
# finding average ex show room price

# soup.find_all('span').text # give error because not only showroom price used span tag
# more elements used this span tag therefore error

# therefore use class of the average ex show room price

for i in soup.find_all('span', class_ = 'o-j5 o-ji o-jJ o-js'):
  print(i.text.strip())
# Out:
# Rs. 17.73 Lakh
# Rs. 10.73 Lakh
# Rs. 10.50 Lakh
# Rs. 13.20 Lakh
# Rs. 13.66 Lakh
# Rs. 10.95 Lakh
# Rs. 12.25 Lakh
# Rs. 18.90 Lakh
# Rs. 10.79 Lakh
# Rs. 14.00 Lakh
# Rs. 18.86 Lakh
# Rs. 18.66 Lakh
# Rs. 12.98 Lakh
# Rs. 21.90 Lakh
# Rs. 14.66 Lakh
# Rs. 21.49 Lakh

# %% [markdown]
# ### 📦 Fetching Complete Car Cards
# ```python
# cars = soup.find_all('div', class_='o-bC o-aE o-f')
# len(cars)
# ```
#
# ---
#
# ### 🎯 Why Fetch Complete Containers?
#
# **The Problem with Separate Extraction:**
#
# - 🔀 **Data gets mixed up** - Can't tell which price belongs to which car
# - 🧩 **No connection** - Car names and prices are separate lists
# - ❌ **Matching nightmare** - Hard to pair data correctly
#
# **The Container Solution:**
#
# - 📦 **One card = One car** - All data stays together
# - ✅ **Organized structure** - Price, mileage, features linked to specific car
# - 🎯 **Easy extraction** - Extract all details from single container
#
# ---
#
# ### 🔍 What This Code Does
#
# | Code | Explanation |
# |------|-------------|
# | `soup.find_all('div', ...)` | Finds all `<div>` containers |
# | `class_='o-bC o-aE o-f'` | Specific class of each car card |
# | `cars` | List of all car card containers |
# | `len(cars)` | Total number of car cards found |
#
# ---
#
# ### 📊 Example Output
# ```python
# len(cars)  # Output: 15
# ```
#
# **Meaning:** Found **15 complete car cards** on the page! 🚗
#
# ---
#
# ### 💡 Next Step
#
# Now you can loop through each `car` container and extract **all its data** together! 🎉
#
# ---

# %%
cars = soup.find_all('div', class_ = 'o-bC o-aE o-f')
len(cars)
# Out:
# 15

# %% [markdown]
# ### 🗂️ Extracting Data from Each Car Card
# ```python
# carNames = []
# exShowRoomPrices = []
#
# for i in cars:
#     # Extract car name
#     name_tag = i.find('h3')
#     if name_tag:
#         carNames.append(name_tag.get_text(strip=True))
#     else:
#         carNames.append(None)
#
#     # Extract price
#     price_tag = i.find('span', class_='o-j5 o-ji o-jJ o-js')
#     if price_tag:
#         exShowRoomPrices.append(price_tag.get_text(strip=True))
#     else:
#         exShowRoomPrices.append(None)
#
# print(exShowRoomPrices)
# ```
#
# ---
#
# ### 🔄 How This Works
#
# **Step-by-Step Process:**
#
# 1. 📋 **Create empty lists** - To store car names and prices
# 2. 🔁 **Loop through each car card** - Process one card at a time
# 3. 🔍 **Find name inside card** - Extract `<h3>` tag
# 4. 💰 **Find price inside card** - Extract price span
# 5. ✅ **Append to lists** - Add data or `None` if missing
# 6. 📊 **Print results** - Display all extracted prices
#
# ---
#
# ### ⚡ `find()` vs `find_all()` - Critical Difference!
#
# | Method | Returns | Use Case | Example |
# |--------|---------|----------|---------|
# | `find()` | **First match only** | Get ONE element per card | `i.find('h3')` → Single name |
# | `find_all()` | **All matches (list)** | Get MULTIPLE elements | `i.find_all('span')` → All spans |
#
# ---
#
# ### 🤔 What If We Used `find_all()` Instead?
# ```python
# # ❌ WRONG: Using find_all()
# name_tag = i.find_all('h3')  # Returns a LIST [<h3>...</h3>]
# carNames.append(name_tag.get_text())  # ERROR! Lists don't have .get_text()
#
# # ✅ CORRECT: Using find()
# name_tag = i.find('h3')  # Returns SINGLE element <h3>...</h3>
# carNames.append(name_tag.get_text())  # Works perfectly!
# ```
#
# **Problem with `find_all()`:**
# - 📦 Returns a **list**, even if only one element exists
# - ❌ Can't directly call `.get_text()` on a list
# - 🔄 Would need extra loop: `for tag in name_tags: tag.get_text()`
#
# ---
#
#
# ### 💡 Key Takeaway
#
# **Use `find()`** when you need **ONE specific element** per container!
# **Use `find_all()`** when you need **MULTIPLE elements** from the same container! 🎯
#
# ---

# %%
carNames = []
exShowRoomPrices = []

for i in cars:
    # Extract car name
    name_tag = i.find('h3')
    if name_tag:
        carNames.append(name_tag.get_text(strip=True))
    else:
        carNames.append(None)

    # Extract price
    price_tag = i.find('span', class_='o-j5 o-ji o-jJ o-js')
    if price_tag:
        exShowRoomPrices.append(price_tag.get_text(strip=True))
    else:
        exShowRoomPrices.append(None)

print(exShowRoomPrices)
print(len(carNames) == len(exShowRoomPrices))
# Out:
# ['Rs. 10.73 Lakh', 'Rs. 10.50 Lakh', 'Rs. 13.20 Lakh', 'Rs. 13.66 Lakh', 'Rs. 10.95 Lakh', 'Rs. 12.25 Lakh', 'Rs. 18.90 Lakh', 'Rs. 10.79 Lakh', 'Rs. 14.00 Lakh', 'Rs. 18.86 Lakh', 'Rs. 18.66 Lakh', 'Rs. 12.98 Lakh', 'Rs. 21.90 Lakh', 'Rs. 14.66 Lakh', 'Rs. 21.49 Lakh']
# True

# %% [markdown]
# ### 📊 Creating a DataFrame
# ```python
# df = pd.DataFrame({
#     'name': carNames,
#     'price': exShowRoomPrices
# })
# ```
#
# ---
#
# ### 🎯 What This Does
#
# **Combines extracted data into a structured table:**
#
# - 📋 **DataFrame** - Pandas table structure for organized data
# - 🏷️ **Columns** - 'name' and 'price' as column headers
# - 📝 **Rows** - Each car as a separate row
# - 🗂️ **Organized** - Easy to view, analyze, and export data
#
# ---
#
# ### 📊 DataFrame Structure
#
# | Column | Data Source | Example Value |
# |--------|-------------|---------------|
# | **name** | `carNames` list | "Tata Nexon" |
# | **price** | `exShowRoomPrices` list | "₹ 8.00 - 15.50 Lakh" |
#
# ---
#
# ### 📝 Output Preview
# ```
#                         name                    price
# 0                 Tata Nexon     ₹ 8.00 - 15.50 Lakh
# 1              Hyundai Creta    ₹ 11.00 - 20.30 Lakh
# 2   Maruti Suzuki Grand Vitara  ₹ 10.99 - 20.09 Lakh
# 3                 Kia Seltos    ₹ 10.90 - 20.35 Lakh
# ...
# ```
#
# ---
#
# ### ✅ Data Ready!
#
# Your scraped car data is now in a **clean, structured format** ready for analysis! 🚗📈
#
# ---

# %%
df = pd.DataFrame({
    'name' : carNames,
    'price': exShowRoomPrices
})

df
# Out:
#                             name           price
# 0                  Hyundai Creta  Rs. 10.73 Lakh
# 1         Maruti Suzuki Victoris  Rs. 10.50 Lakh
# 2             Mahindra Scorpio N  Rs. 13.20 Lakh
# 3                Mahindra XUV700  Rs. 13.66 Lakh
# 4   Toyota Urban Cruiser Hyryder  Rs. 10.95 Lakh
# 5             Mahindra Thar Roxx  Rs. 12.25 Lakh
# 6                  Mahindra BE 6  Rs. 18.90 Lakh
# 7                     Kia Seltos  Rs. 10.79 Lakh
# 8                   Tata Harrier  Rs. 14.00 Lakh
# 9          Toyota Innova Hycross  Rs. 18.86 Lakh
# 10          Toyota Innova Crysta  Rs. 18.66 Lakh
# 11              Mahindra Scorpio  Rs. 12.98 Lakh
# 12               Mahindra XEV 9e  Rs. 21.90 Lakh
# 13                   Tata Safari  Rs. 14.66 Lakh
# 14               Tata Harrier EV  Rs. 21.49 Lakh

# %%
df.shape
# Out:
# (15, 2)

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'
}

carNames = []
exShowRoomPrices = []

# Loop over 7 pages
for i in range(1, 8):
    url = f'https://www.carwale.com/new/best-cars-under-30-lakh/{i}/'
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'lxml')

    cars = soup.find_all('div', class_ = 'o-bC o-aE o-f')

    for j in cars :
      name_tag = j.find('h3')
      if name_tag:
          carNames.append(name_tag.get_text(strip=True))
      else:
          carNames.append(None)

      # Extract price
      price_tag = j.find('span', class_='o-j5 o-ji o-jJ o-js')
      if price_tag:
          exShowRoomPrices.append(price_tag.get_text(strip=True))
      else:
          exShowRoomPrices.append(None)

df = pd.DataFrame({
    'name' : carNames,
    'price' : exShowRoomPrices
})

df
# Out:
#                              name           price
# 0                   Hyundai Creta  Rs. 10.73 Lakh
# 1          Maruti Suzuki Victoris  Rs. 10.50 Lakh
# 2              Mahindra Scorpio N  Rs. 13.20 Lakh
# 3                 Mahindra XUV700  Rs. 13.66 Lakh
# 4    Toyota Urban Cruiser Hyryder  Rs. 10.95 Lakh
# ..                            ...             ...
# 97                   Renault Kwid   Rs. 4.30 Lakh
# 98          Maruti Suzuki Celerio   Rs. 4.70 Lakh
# 99         Maruti Suzuki S-Presso   Rs. 3.50 Lakh
# 100            Maruti Suzuki Eeco   Rs. 5.21 Lakh
# 101                Tata Tiago NRG   Rs. 6.68 Lakh
#
# [102 rows x 2 columns]
